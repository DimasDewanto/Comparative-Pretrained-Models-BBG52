# %%
# Setup Awal
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, ConcatDataset
from torchvision import datasets, models, transforms
from torchvision.transforms import RandAugment
import time
import copy
import numpy as np
from sklearn.metrics import f1_score, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# Config
torch.manual_seed(42)
np.random.seed(42)
batch_size = 32
learning_rate = 0.001
num_epochs = 50
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Menggunakan device: {device}")

# Direktori dataset
train_dir = 'C:/Users/ASUS/Downloads/Dataset Random/train'
val_dir = 'C:/Users/ASUS/Downloads/Dataset Random/val'
# Out:
# Menggunakan device: cuda

# %%
# Data Preprocessing
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'aug': transforms.Compose([
        RandAugment(num_ops=2, magnitude=9),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

train_dataset_base = datasets.ImageFolder(train_dir, data_transforms['train'])
train_dataset_aug  = datasets.ImageFolder(train_dir, data_transforms['aug'])
train_dataset_concat = ConcatDataset([train_dataset_base, train_dataset_aug])

# Load dataset
image_datasets = {
    'train': train_dataset_concat,
    'val': datasets.ImageFolder(val_dir, data_transforms['val'])
}

dataloaders = {
    'train': DataLoader(image_datasets['train'], batch_size=batch_size, shuffle=True, num_workers=4),
    'val': DataLoader(image_datasets['val'], batch_size=batch_size, shuffle=False, num_workers=4)
}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
num_classes = image_datasets['train'].datasets[0].classes

print(f"Class names: {num_classes}")
print(f"Jumlah kelas: {len(num_classes)}")
print(f"Ukuran dataset - train : {dataset_sizes['train']}, val: {dataset_sizes['val']}")
# Out:
# Class names: ['Acalypha siamensis Oliv. ex Gage', 'Acalypha wilkesiana Müll.Arg', 'Agathis borneensis Warburg', 'Agave demeesteriana Jacobi', 'Allamanda cathartica L', 'Alocasia macrorrhizos', 'Aloe vera (L.) Burm.f', 'Alstonia angustiloba Miq', 'Alstonia iwahigensis Elmer', 'Amorphophallus paeoniifolius (Dennst.) Nicolson', 'Asystasia gangetica (L.) T.Anderson', 'Borassodendron borneensis J. Dransf', 'Bougainvillea spectabilis', 'Cocos nucifera L', 'Codiaeum variegatum (L.) Rumph. ex A.Juss', 'Cordyline fruticosa (L.) A. Chev', 'Cornus alba L', 'Costus woodsonii Maas', 'Ctenanthe burle-marxii H.Kenn', 'Dillenia sp', 'Diospyros borneensis Hiern', 'Diospyros confertiflora Hiern', 'Dracaena reflexa Lam', 'Dracaena trifasciata (Prain) Mabb', 'Duranta erecta L', 'Eusideroxylon zwageri Teijsm. & Binn', 'Excoecaria cochinchinensis Lour', 'Furcraea foetida (L.) Haw', 'Garcinia mangostana L', 'Grammatophyllum speciosum', 'Hibiscus rosa-sinensis L', 'Hopea pedicellata (Brandis) Symington', 'Hura crepitans L', 'Ixora javanica', 'Kalanchoe pinnata', 'Koompassia excelsa (Becc.) Taub', 'Licuala spinosa', 'Mangifera indica L', 'Mussaenda philippica', 'Nepenthes mirabilis Druce', 'Pandanus amaryllifolius Roxb', 'Pandanus pygmaeus Thouars', 'Plumeria sp', 'Ruellia simplex C.Wright', 'Saraca declinata Miq', 'Shorea laevis Ridl', 'Strombosia ceylanica Gardn', 'Syzygium oleana', 'Tabernaemontana divaricata (L.) R.Br. ex Roem. & Schult', 'Terminalia mantaly H.Perrier', 'Vatica oblongifolia Hook.f', 'Vatica umbonata Burck']
# Jumlah kelas: 52
# Ukuran dataset - train : 6240, val: 2079

# %%
# Fungsi Inisialisasi Model
from torchvision.models import ResNet50_Weights, MobileNet_V3_Large_Weights, DenseNet121_Weights, ConvNeXt_Tiny_Weights

def initialize_model(model_name, scenario):
    model = None

    if model_name == 'ResNet50':
        model = models.resnet50(weights='IMAGENET1K_V1')
        if scenario == 'no_hidden':
            model.fc = nn.Linear(model.fc.in_features, len(num_classes))
        else:
            model.fc = nn.Sequential(
                nn.Linear(model.fc.in_features, 512),
                nn.ReLU(),
                nn.Dropout(0.5),
                nn.Linear(512, len(num_classes))
            )
        # Freeze semua layer kecuali fc
        for param in model.parameters():
            param.requires_grad = False
        for param in model.fc.parameters():
            param.requires_grad = True

    elif model_name == 'DenseNet121':
        model = models.densenet121(weights='IMAGENET1K_V1')
        if scenario == 'no_hidden':
            model.classifier = nn.Linear(model.classifier.in_features, len(num_classes))
        else:
            model.classifier = nn.Sequential(
                nn.Linear(model.classifier.in_features, 512),
                nn.ReLU(),
                nn.Dropout(0.5),
                nn.Linear(512, len(num_classes))
            )
        # Freeze semua layer kecuali classifier
        for param in model.parameters():
            param.requires_grad = False
        for param in model.classifier.parameters():
            param.requires_grad = True
                
    elif model_name == 'MobileNetV3':
        model = models.mobilenet_v3_large(weights='IMAGENET1K_V1')
        if scenario == 'no_hidden':
            model.classifier[-1] = nn.Linear(model.classifier[-1].in_features, len(num_classes))
        else:
            model.classifier[-1] = nn.Sequential(
                nn.Linear(model.classifier[-1].in_features, 512),
                nn.Hardswish(),
                nn.Dropout(0.5),
                nn.Linear(512, len(num_classes))
            )
        # Freeze semua layer kecuali classifier
        for param in model.parameters():
            param.requires_grad = False
        for param in model.classifier.parameters():
            param.requires_grad = True

    elif model_name == 'ConvNeXt':
        model = models.convnext_tiny(weights='IMAGENET1K_V1')
        if scenario == 'no_hidden':
            model.classifier = nn.Sequential(
                nn.Flatten(1),
                nn.LayerNorm([model.classifier[-1].in_features], eps=1e-6),
                nn.Linear(model.classifier[-1].in_features, len(num_classes))
            )
        else:
            model.classifier = nn.Sequential(
                nn.Flatten(1),
                nn.LayerNorm([model.classifier[-1].in_features], eps=1e-6),
                nn.Linear(model.classifier[-1].in_features, 512),
                nn.GELU(),
                nn.Dropout(0.5),
                nn.Linear(512, len(num_classes))
            )
        # Freeze semua layer kecuali classifier
        for param in model.parameters():
            param.requires_grad = False
        for param in model.classifier.parameters():
            param.requires_grad = True

    return model.to(device)

# %%
# Fungsi Train&Val
def train_model(model, model_name, scenario):
    print(f'\n=== Model: {model_name} | Skenario: {scenario} ===\n')
    since = time.time()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    history = {
        'train_loss': [], 'train_acc': [], 'train_f1': [],
        'val_loss': [], 'val_acc': [], 'val_f1': []
    }

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_f1 = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1} / {num_epochs}')
        print('-' * 10)
        eptm = time.time()
        
        # Training Phase
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        train_preds, train_targets = [], []

        for inputs, labels in dataloaders['train']:
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (preds == labels).sum().item()
            
            train_preds.extend(preds.cpu().numpy())
            train_targets.extend(labels.cpu().numpy())
            
        # Hitung semua metrik
        epoch_train_loss = running_loss / len(image_datasets['train'])
        epoch_train_acc = 100 * correct_train / total_train
        epoch_train_f1 = f1_score(train_targets, train_preds, average='macro')

        # Validation Phase
        model.eval()
        val_running_loss = 0.0
        correct_val = 0
        total_val = 0
        val_preds, val_targets = [], []

        with torch.no_grad():
            for inputs, labels in dataloaders['val']:
                inputs, labels = inputs.to(device), labels.to(device)
                
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_running_loss += loss.item() * inputs.size(0)
                
                _, preds = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (preds == labels).sum().item()
                
                val_preds.extend(preds.cpu().numpy())
                val_targets.extend(labels.cpu().numpy())

        # Hitung semua metrik
        epoch_val_loss = val_running_loss / len(image_datasets['val'])
        epoch_val_acc = 100 * correct_val / total_val
        epoch_val_f1 = f1_score(val_targets, val_preds, average='macro')

        # Update history
        history['train_loss'].append(epoch_train_loss)
        history['train_acc'].append(epoch_train_acc)
        history['train_f1'].append(epoch_train_f1)
        history['val_loss'].append(epoch_val_loss)
        history['val_acc'].append(epoch_val_acc)
        history['val_f1'].append(epoch_val_f1)

        # Simpan model terbaik
        if epoch_val_acc > best_acc:
            best_acc = epoch_val_acc
            best_model_wts = copy.deepcopy(model.state_dict())
        if epoch_val_f1 > best_f1:
            best_f1 = epoch_val_f1
        
        epoch_time = time.time() - eptm
        print(f'Train Loss: {epoch_train_loss:.4f} Acc: {epoch_train_acc:.4f} F1: {epoch_train_f1:.4f} | '
              f'Val Loss: {epoch_val_loss:.4f} Acc: {epoch_val_acc:.4f}% F1: {epoch_val_f1:.4f} | '
              f'Epoch time: {epoch_time // 60:.0f}m {epoch_time % 60:.0f}s\n')
        
    time_elapsed = time.time() - since
    print(f'Training {model_name} {scenario} complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')
    print(f'Best val F1: {best_f1:4f}\n')
    visualize_training(history)

    # Save model
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), f'C:/Users/ASUS/Coding/Jupiter/PRTA/{model_name}_{scenario}.pth')

    return {
        'model_name': model_name,
        'scenario': scenario,
        'train_time': time_elapsed,
        'history': history
    }


def visualize_training(history):
    plt.figure(figsize=(15, 5))

    # Plot loss
    plt.subplot(1, 3, 1)
    plt.plot(history['train_loss'], label='train')
    plt.plot(history['val_loss'], label='val')
    plt.title('Loss over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 3, 2)
    plt.plot(history['train_acc'], label='train')
    plt.plot(history['val_acc'], label='val')
    plt.title('Accuracy over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot F1-score
    plt.subplot(1, 3, 3)
    plt.plot(history['val_f1'], label='val')
    plt.title('Validation F1-score over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('F1-score')
    plt.legend()

    plt.tight_layout()
    plt.show()

    
# Menyimpan hasil training
results_training = []

# %%
# ResNet50
#Tanpa Hidden Layer
model = initialize_model('ResNet50', 'no_hidden')
res = train_model(model, 'ResNet50', 'no_hidden')
results_training.append(res)

#Dengan Hidden Layer
model = initialize_model('ResNet50', 'with_hidden')
res = train_model(model, 'ResNet50', 'with_hidden')
results_training.append(res)
# Out:
# === Model: ResNet50 | Skenario: no_hidden ===
#
# Epoch 1 / 50
# ----------
# Train Loss: 2.0074 Acc: 54.7756 F1: 0.5451 | Val Loss: 0.6648 Acc: 86.4839% F1: 0.8601 | Epoch time: 1m 18s
#
# Epoch 2 / 50
# ----------
# Train Loss: 0.9267 Acc: 77.1795 F1: 0.7706 | Val Loss: 0.4379 Acc: 88.8408% F1: 0.8843 | Epoch time: 1m 16s
#
# Epoch 3 / 50
# ----------
# Train Loss: 0.7448 Acc: 80.3205 F1: 0.8026 | Val Loss: 0.3416 Acc: 90.2838% F1: 0.8998 | Epoch time: 1m 17s
#
# Epoch 4 / 50
# ----------
# Train Loss: 0.6307 Acc: 83.3173 F1: 0.8331 | Val Loss: 0.2851 Acc: 92.2078% F1: 0.9198 | Epoch time: 1m 17s
#
# Epoch 5 / 50
# ----------
# Train Loss: 0.5734 Acc: 84.5353 F1: 0.8449 | Val Loss: 0.3037 Acc: 90.9572% F1: 0.9093 | Epoch time: 1m 17s
#
# Epoch 6 / 50
# ----------
# Train Loss: 0.5397 Acc: 85.0481 F1: 0.8505 | Val Loss: 0.2368 Acc: 93.4103% F1: 0.9332 | Epoch time: 1m 17s
#
# Epoch 7 / 50
# ----------
# Train Loss: 0.5470 Acc: 84.6154 F1: 0.8456 | Val Loss: 0.2290 Acc: 93.6027% F1: 0.9356 | Epoch time: 1m 17s
#
# Epoch 8 / 50
# ----------
# Train Loss: 0.5051 Acc: 85.4327 F1: 0.8542 | Val Loss: 0.2129 Acc: 94.3723% F1: 0.9428 | Epoch time: 1m 16s
#
# Epoch 9 / 50
# ----------
# Train Loss: 0.4766 Acc: 86.2179 F1: 0.8620 | Val Loss: 0.2357 Acc: 92.8812% F1: 0.9283 | Epoch time: 1m 16s
#
# Epoch 10 / 50
# ----------
# Train Loss: 0.4722 Acc: 86.4583 F1: 0.8645 | Val Loss: 0.2083 Acc: 93.6989% F1: 0.9364 | Epoch time: 1m 17s
#
# Epoch 11 / 50
# ----------
# Train Loss: 0.4584 Acc: 85.9776 F1: 0.8596 | Val Loss: 0.2167 Acc: 93.7470% F1: 0.9362 | Epoch time: 1m 17s
#
# Epoch 12 / 50
# ----------
# Train Loss: 0.4340 Acc: 87.0192 F1: 0.8699 | Val Loss: 0.2062 Acc: 93.8432% F1: 0.9381 | Epoch time: 1m 16s
#
# Epoch 13 / 50
# ----------
# Train Loss: 0.4300 Acc: 87.5801 F1: 0.8759 | Val Loss: 0.1887 Acc: 94.4204% F1: 0.9448 | Epoch time: 1m 17s
#
# Epoch 14 / 50
# ----------
# Train Loss: 0.4159 Acc: 87.6603 F1: 0.8766 | Val Loss: 0.1759 Acc: 94.7571% F1: 0.9478 | Epoch time: 1m 17s
#
# Epoch 15 / 50
# ----------
# Train Loss: 0.4217 Acc: 87.5321 F1: 0.8752 | Val Loss: 0.2027 Acc: 93.6508% F1: 0.9370 | Epoch time: 1m 16s
#
# Epoch 16 / 50
# ----------
# Train Loss: 0.3803 Acc: 89.1827 F1: 0.8917 | Val Loss: 0.1610 Acc: 95.2381% F1: 0.9522 | Epoch time: 1m 16s
#
# Epoch 17 / 50
# ----------
# Train Loss: 0.4171 Acc: 87.5481 F1: 0.8755 | Val Loss: 0.1999 Acc: 94.0837% F1: 0.9402 | Epoch time: 1m 16s
#
# Epoch 18 / 50
# ----------
# Train Loss: 0.4173 Acc: 87.3558 F1: 0.8734 | Val Loss: 0.1837 Acc: 94.5166% F1: 0.9445 | Epoch time: 1m 17s
#
# Epoch 19 / 50
# ----------
# Train Loss: 0.3840 Acc: 88.9744 F1: 0.8896 | Val Loss: 0.1803 Acc: 94.6609% F1: 0.9479 | Epoch time: 1m 16s
#
# Epoch 20 / 50
# ----------
# Train Loss: 0.4042 Acc: 88.6378 F1: 0.8867 | Val Loss: 0.1726 Acc: 95.1900% F1: 0.9521 | Epoch time: 1m 16s
#
# Epoch 21 / 50
# ----------
# Train Loss: 0.3864 Acc: 88.6699 F1: 0.8866 | Val Loss: 0.1615 Acc: 95.4786% F1: 0.9555 | Epoch time: 1m 17s
#
# Epoch 22 / 50
# ----------
# Train Loss: 0.3862 Acc: 88.5737 F1: 0.8855 | Val Loss: 0.1678 Acc: 95.4786% F1: 0.9552 | Epoch time: 1m 17s
#
# Epoch 23 / 50
# ----------
# Train Loss: 0.3735 Acc: 89.1667 F1: 0.8915 | Val Loss: 0.1557 Acc: 95.1900% F1: 0.9524 | Epoch time: 1m 17s
#
# Epoch 24 / 50
# ----------
# Train Loss: 0.3921 Acc: 88.7500 F1: 0.8875 | Val Loss: 0.1921 Acc: 94.0837% F1: 0.9411 | Epoch time: 1m 17s
#
# Epoch 25 / 50
# ----------
# Train Loss: 0.3916 Acc: 88.4615 F1: 0.8845 | Val Loss: 0.1528 Acc: 95.2862% F1: 0.9527 | Epoch time: 1m 17s
#
# Epoch 26 / 50
# ----------
# Train Loss: 0.3628 Acc: 89.0545 F1: 0.8904 | Val Loss: 0.1770 Acc: 94.9014% F1: 0.9481 | Epoch time: 1m 16s
#
# Epoch 27 / 50
# ----------
# Train Loss: 0.3522 Acc: 89.5994 F1: 0.8958 | Val Loss: 0.1925 Acc: 94.3242% F1: 0.9430 | Epoch time: 1m 17s
#
# Epoch 28 / 50
# ----------
# Train Loss: 0.3598 Acc: 89.4231 F1: 0.8943 | Val Loss: 0.1829 Acc: 94.8533% F1: 0.9488 | Epoch time: 1m 17s
#
# Epoch 29 / 50
# ----------
# Train Loss: 0.3734 Acc: 89.3269 F1: 0.8931 | Val Loss: 0.1628 Acc: 95.1900% F1: 0.9517 | Epoch time: 1m 16s
#
# Epoch 30 / 50
# ----------
# Train Loss: 0.3540 Acc: 89.3590 F1: 0.8935 | Val Loss: 0.1787 Acc: 94.3723% F1: 0.9441 | Epoch time: 1m 16s
#
# Epoch 31 / 50
# ----------
# Train Loss: 0.3659 Acc: 89.1827 F1: 0.8919 | Val Loss: 0.1729 Acc: 94.6128% F1: 0.9460 | Epoch time: 1m 16s
#
# Epoch 32 / 50
# ----------
# Train Loss: 0.3649 Acc: 89.5673 F1: 0.8956 | Val Loss: 0.1438 Acc: 95.8153% F1: 0.9580 | Epoch time: 1m 17s
#
# Epoch 33 / 50
# ----------
# Train Loss: 0.3489 Acc: 89.7596 F1: 0.8975 | Val Loss: 0.1455 Acc: 96.0077% F1: 0.9598 | Epoch time: 1m 16s
#
# Epoch 34 / 50
# ----------
# Train Loss: 0.3492 Acc: 90.0641 F1: 0.9004 | Val Loss: 0.1652 Acc: 94.9976% F1: 0.9497 | Epoch time: 1m 16s
#
# Epoch 35 / 50
# ----------
# Train Loss: 0.3490 Acc: 89.8558 F1: 0.8985 | Val Loss: 0.1382 Acc: 95.9115% F1: 0.9592 | Epoch time: 1m 16s
#
# Epoch 36 / 50
# ----------
# Train Loss: 0.3271 Acc: 90.7853 F1: 0.9078 | Val Loss: 0.1699 Acc: 94.6128% F1: 0.9458 | Epoch time: 1m 16s
#
# Epoch 37 / 50
# ----------
# Train Loss: 0.3168 Acc: 90.8974 F1: 0.9089 | Val Loss: 0.1603 Acc: 94.8533% F1: 0.9482 | Epoch time: 1m 16s
#
# Epoch 38 / 50
# ----------
# Train Loss: 0.3764 Acc: 89.2147 F1: 0.8921 | Val Loss: 0.1590 Acc: 95.4786% F1: 0.9551 | Epoch time: 1m 17s
#
# Epoch 39 / 50
# ----------
# Train Loss: 0.3485 Acc: 89.6955 F1: 0.8970 | Val Loss: 0.1547 Acc: 95.1900% F1: 0.9527 | Epoch time: 1m 17s
#
# Epoch 40 / 50
# ----------
# Train Loss: 0.3138 Acc: 90.6090 F1: 0.9060 | Val Loss: 0.1380 Acc: 96.1520% F1: 0.9615 | Epoch time: 1m 17s
#
# Epoch 41 / 50
# ----------
# Train Loss: 0.3348 Acc: 89.7276 F1: 0.8971 | Val Loss: 0.1606 Acc: 95.6229% F1: 0.9570 | Epoch time: 1m 16s
#
# Epoch 42 / 50
# ----------
# Train Loss: 0.3664 Acc: 89.5994 F1: 0.8960 | Val Loss: 0.1568 Acc: 94.9495% F1: 0.9496 | Epoch time: 1m 16s
#
# Epoch 43 / 50
# ----------
# Train Loss: 0.3408 Acc: 90.3045 F1: 0.9029 | Val Loss: 0.2145 Acc: 93.5065% F1: 0.9359 | Epoch time: 1m 17s
#
# Epoch 44 / 50
# ----------
# Train Loss: 0.3253 Acc: 90.4808 F1: 0.9047 | Val Loss: 0.1280 Acc: 96.1520% F1: 0.9613 | Epoch time: 1m 17s
#
# Epoch 45 / 50
# ----------
# Train Loss: 0.3327 Acc: 90.1122 F1: 0.9010 | Val Loss: 0.1642 Acc: 95.5267% F1: 0.9556 | Epoch time: 1m 17s
#
# Epoch 46 / 50
# ----------
# Train Loss: 0.3374 Acc: 89.7436 F1: 0.8975 | Val Loss: 0.1556 Acc: 95.8153% F1: 0.9587 | Epoch time: 1m 18s
#
# Epoch 47 / 50
# ----------
# Train Loss: 0.3421 Acc: 90.1763 F1: 0.9017 | Val Loss: 0.1457 Acc: 95.6710% F1: 0.9573 | Epoch time: 1m 17s
#
# Epoch 48 / 50
# ----------
# Train Loss: 0.3319 Acc: 90.4487 F1: 0.9043 | Val Loss: 0.1507 Acc: 95.5748% F1: 0.9562 | Epoch time: 1m 17s
#
# Epoch 49 / 50
# ----------
# Train Loss: 0.3410 Acc: 90.0000 F1: 0.8998 | Val Loss: 0.1491 Acc: 96.1039% F1: 0.9615 | Epoch time: 1m 16s
#
# Epoch 50 / 50
# ----------
# Train Loss: 0.3033 Acc: 90.7051 F1: 0.9070 | Val Loss: 0.1571 Acc: 95.5748% F1: 0.9559 | Epoch time: 1m 16s
#
# Training ResNet50 no_hidden complete in 63m 51s
# Best val Acc: 96.151996
# Best val F1: 0.961484
# === Model: ResNet50 | Skenario: with_hidden ===
#
# Epoch 1 / 50
# ----------
# Train Loss: 2.9223 Acc: 26.8429 F1: 0.2573 | Val Loss: 1.3128 Acc: 74.5551% F1: 0.7291 | Epoch time: 1m 16s
#
# Epoch 2 / 50
# ----------
# Train Loss: 1.7252 Acc: 52.5321 F1: 0.5146 | Val Loss: 0.7082 Acc: 83.8384% F1: 0.8309 | Epoch time: 1m 17s
#
# Epoch 3 / 50
# ----------
# Train Loss: 1.3765 Acc: 61.6506 F1: 0.6096 | Val Loss: 0.5311 Acc: 86.2434% F1: 0.8581 | Epoch time: 1m 16s
#
# Epoch 4 / 50
# ----------
# Train Loss: 1.2457 Acc: 64.4872 F1: 0.6395 | Val Loss: 0.5063 Acc: 87.3978% F1: 0.8744 | Epoch time: 1m 17s
#
# Epoch 5 / 50
# ----------
# Train Loss: 1.1729 Acc: 66.7468 F1: 0.6633 | Val Loss: 0.4144 Acc: 89.9952% F1: 0.8986 | Epoch time: 1m 17s
#
# Epoch 6 / 50
# ----------
# Train Loss: 1.0922 Acc: 68.8301 F1: 0.6844 | Val Loss: 0.3904 Acc: 89.1775% F1: 0.8907 | Epoch time: 1m 17s
#
# Epoch 7 / 50
# ----------
# Train Loss: 1.0458 Acc: 69.4551 F1: 0.6914 | Val Loss: 0.3535 Acc: 90.3800% F1: 0.9036 | Epoch time: 1m 17s
#
# Epoch 8 / 50
# ----------
# Train Loss: 1.0344 Acc: 69.8718 F1: 0.6958 | Val Loss: 0.3207 Acc: 91.1015% F1: 0.9106 | Epoch time: 1m 17s
#
# Epoch 9 / 50
# ----------
# Train Loss: 1.0243 Acc: 70.4006 F1: 0.7010 | Val Loss: 0.3108 Acc: 91.6787% F1: 0.9168 | Epoch time: 1m 16s
#
# Epoch 10 / 50
# ----------
# Train Loss: 0.9657 Acc: 72.5160 F1: 0.7231 | Val Loss: 0.2938 Acc: 91.1977% F1: 0.9119 | Epoch time: 1m 16s
#
# Epoch 11 / 50
# ----------
# Train Loss: 0.9602 Acc: 71.8910 F1: 0.7158 | Val Loss: 0.2997 Acc: 90.7648% F1: 0.9079 | Epoch time: 1m 17s
#
# Epoch 12 / 50
# ----------
# Train Loss: 0.9762 Acc: 71.7788 F1: 0.7158 | Val Loss: 0.2829 Acc: 92.0154% F1: 0.9196 | Epoch time: 1m 16s
#
# Epoch 13 / 50
# ----------
# Train Loss: 0.9325 Acc: 72.2436 F1: 0.7205 | Val Loss: 0.2836 Acc: 92.1116% F1: 0.9199 | Epoch time: 1m 17s
#
# Epoch 14 / 50
# ----------
# Train Loss: 0.9182 Acc: 72.9968 F1: 0.7275 | Val Loss: 0.2536 Acc: 92.7850% F1: 0.9277 | Epoch time: 1m 16s
#
# Epoch 15 / 50
# ----------
# Train Loss: 0.9011 Acc: 73.9103 F1: 0.7375 | Val Loss: 0.2833 Acc: 92.1597% F1: 0.9227 | Epoch time: 1m 17s
#
# Epoch 16 / 50
# ----------
# Train Loss: 0.8855 Acc: 74.1346 F1: 0.7391 | Val Loss: 0.2674 Acc: 91.9192% F1: 0.9181 | Epoch time: 1m 16s
#
# Epoch 17 / 50
# ----------
# Train Loss: 0.9010 Acc: 73.6699 F1: 0.7349 | Val Loss: 0.2525 Acc: 92.2559% F1: 0.9213 | Epoch time: 1m 16s
#
# Epoch 18 / 50
# ----------
# Train Loss: 0.8696 Acc: 73.9744 F1: 0.7372 | Val Loss: 0.2566 Acc: 92.3521% F1: 0.9224 | Epoch time: 1m 17s
#
# Epoch 19 / 50
# ----------
# Train Loss: 0.8529 Acc: 74.9199 F1: 0.7475 | Val Loss: 0.2479 Acc: 92.4002% F1: 0.9221 | Epoch time: 1m 17s
#
# Epoch 20 / 50
# ----------
# Train Loss: 0.8657 Acc: 74.1026 F1: 0.7387 | Val Loss: 0.2249 Acc: 93.1698% F1: 0.9320 | Epoch time: 1m 16s
#
# Epoch 21 / 50
# ----------
# Train Loss: 0.8692 Acc: 74.5353 F1: 0.7438 | Val Loss: 0.2417 Acc: 92.6888% F1: 0.9266 | Epoch time: 1m 16s
#
# Epoch 22 / 50
# ----------
# Train Loss: 0.8241 Acc: 75.5449 F1: 0.7536 | Val Loss: 0.2351 Acc: 92.4964% F1: 0.9247 | Epoch time: 1m 17s
#
# Epoch 23 / 50
# ----------
# Train Loss: 0.8700 Acc: 74.0064 F1: 0.7382 | Val Loss: 0.2160 Acc: 93.2660% F1: 0.9331 | Epoch time: 1m 16s
#
# Epoch 24 / 50
# ----------
# Train Loss: 0.8270 Acc: 74.9038 F1: 0.7477 | Val Loss: 0.2210 Acc: 93.6989% F1: 0.9371 | Epoch time: 1m 17s
#
# Epoch 25 / 50
# ----------
# Train Loss: 0.8320 Acc: 75.5929 F1: 0.7540 | Val Loss: 0.2375 Acc: 92.8812% F1: 0.9287 | Epoch time: 1m 17s
#
# Epoch 26 / 50
# ----------
# Train Loss: 0.8524 Acc: 74.8878 F1: 0.7473 | Val Loss: 0.2287 Acc: 92.6888% F1: 0.9264 | Epoch time: 1m 17s
#
# Epoch 27 / 50
# ----------
# Train Loss: 0.8281 Acc: 75.1442 F1: 0.7505 | Val Loss: 0.2156 Acc: 93.5546% F1: 0.9344 | Epoch time: 1m 17s
#
# Epoch 28 / 50
# ----------
# Train Loss: 0.8410 Acc: 75.5609 F1: 0.7538 | Val Loss: 0.2078 Acc: 93.6027% F1: 0.9358 | Epoch time: 1m 17s
#
# Epoch 29 / 50
# ----------
# Train Loss: 0.8406 Acc: 74.8718 F1: 0.7469 | Val Loss: 0.2235 Acc: 92.7850% F1: 0.9276 | Epoch time: 1m 17s
#
# Epoch 30 / 50
# ----------
# Train Loss: 0.8083 Acc: 75.8494 F1: 0.7573 | Val Loss: 0.1991 Acc: 94.0356% F1: 0.9410 | Epoch time: 1m 17s
#
# Epoch 31 / 50
# ----------
# Train Loss: 0.8341 Acc: 75.7212 F1: 0.7556 | Val Loss: 0.2082 Acc: 93.4584% F1: 0.9348 | Epoch time: 1m 17s
#
# Epoch 32 / 50
# ----------
# Train Loss: 0.8374 Acc: 74.9519 F1: 0.7480 | Val Loss: 0.2057 Acc: 94.1799% F1: 0.9418 | Epoch time: 1m 16s
#
# Epoch 33 / 50
# ----------
# Train Loss: 0.8080 Acc: 75.9776 F1: 0.7586 | Val Loss: 0.2026 Acc: 94.1799% F1: 0.9418 | Epoch time: 1m 17s
#
# Epoch 34 / 50
# ----------
# Train Loss: 0.7950 Acc: 76.0737 F1: 0.7597 | Val Loss: 0.2113 Acc: 93.8913% F1: 0.9400 | Epoch time: 1m 16s
#
# Epoch 35 / 50
# ----------
# Train Loss: 0.7955 Acc: 76.3782 F1: 0.7627 | Val Loss: 0.2005 Acc: 94.1799% F1: 0.9418 | Epoch time: 1m 17s
#
# Epoch 36 / 50
# ----------
# Train Loss: 0.7978 Acc: 75.7372 F1: 0.7557 | Val Loss: 0.2158 Acc: 93.3141% F1: 0.9327 | Epoch time: 1m 17s
#
# Epoch 37 / 50
# ----------
# Train Loss: 0.7978 Acc: 76.4904 F1: 0.7636 | Val Loss: 0.2040 Acc: 93.4584% F1: 0.9347 | Epoch time: 1m 17s
#
# Epoch 38 / 50
# ----------
# Train Loss: 0.7879 Acc: 75.9295 F1: 0.7578 | Val Loss: 0.2074 Acc: 93.7951% F1: 0.9388 | Epoch time: 1m 17s
#
# Epoch 39 / 50
# ----------
# Train Loss: 0.8023 Acc: 76.2981 F1: 0.7620 | Val Loss: 0.1975 Acc: 94.1799% F1: 0.9421 | Epoch time: 1m 17s
#
# Epoch 40 / 50
# ----------
# Train Loss: 0.7555 Acc: 77.6442 F1: 0.7750 | Val Loss: 0.1944 Acc: 94.0837% F1: 0.9406 | Epoch time: 1m 17s
#
# Epoch 41 / 50
# ----------
# Train Loss: 0.8127 Acc: 75.8974 F1: 0.7579 | Val Loss: 0.2128 Acc: 93.7951% F1: 0.9380 | Epoch time: 1m 17s
#
# Epoch 42 / 50
# ----------
# Train Loss: 0.7916 Acc: 76.6506 F1: 0.7654 | Val Loss: 0.2105 Acc: 93.6508% F1: 0.9372 | Epoch time: 1m 16s
#
# Epoch 43 / 50
# ----------
# Train Loss: 0.7699 Acc: 77.0192 F1: 0.7688 | Val Loss: 0.1985 Acc: 94.0356% F1: 0.9397 | Epoch time: 1m 18s
#
# Epoch 44 / 50
# ----------
# Train Loss: 0.7831 Acc: 76.6827 F1: 0.7659 | Val Loss: 0.1898 Acc: 94.4204% F1: 0.9445 | Epoch time: 1m 17s
#
# Epoch 45 / 50
# ----------
# Train Loss: 0.7637 Acc: 77.8205 F1: 0.7764 | Val Loss: 0.1862 Acc: 94.0356% F1: 0.9409 | Epoch time: 1m 16s
#
# Epoch 46 / 50
# ----------
# Train Loss: 0.7705 Acc: 76.9231 F1: 0.7681 | Val Loss: 0.1884 Acc: 94.4204% F1: 0.9443 | Epoch time: 1m 16s
#
# Epoch 47 / 50
# ----------
# Train Loss: 0.7937 Acc: 76.1378 F1: 0.7605 | Val Loss: 0.2069 Acc: 93.6508% F1: 0.9369 | Epoch time: 1m 17s
#
# Epoch 48 / 50
# ----------
# Train Loss: 0.7814 Acc: 77.2436 F1: 0.7716 | Val Loss: 0.1973 Acc: 93.8432% F1: 0.9374 | Epoch time: 1m 16s
#
# Epoch 49 / 50
# ----------
# Train Loss: 0.7800 Acc: 76.9712 F1: 0.7683 | Val Loss: 0.1924 Acc: 94.2280% F1: 0.9422 | Epoch time: 1m 17s
#
# Epoch 50 / 50
# ----------
# Train Loss: 0.7817 Acc: 77.0032 F1: 0.7684 | Val Loss: 0.1845 Acc: 93.8432% F1: 0.9383 | Epoch time: 1m 16s
#
# Training ResNet50 with_hidden complete in 63m 51s
# Best val Acc: 94.420394
# Best val F1: 0.944547

# %%
# DenseNet121
#Tanpa Hidden Layer
model = initialize_model('DenseNet121', 'no_hidden')
res = train_model(model, 'DenseNet121', 'no_hidden')
results_training.append(res)

#Dengan Hidden Layer
model = initialize_model('DenseNet121', 'with_hidden')
res = train_model(model, 'DenseNet121', 'with_hidden')
results_training.append(res)
# Out:
# === Model: DenseNet121 | Skenario: no_hidden ===
#
# Epoch 1 / 50
# ----------
# Train Loss: 2.4313 Acc: 48.8622 F1: 0.4822 | Val Loss: 1.0670 Acc: 82.7802% F1: 0.8162 | Epoch time: 1m 19s
#
# Epoch 2 / 50
# ----------
# Train Loss: 1.1424 Acc: 76.9551 F1: 0.7671 | Val Loss: 0.6182 Acc: 89.2256% F1: 0.8904 | Epoch time: 1m 18s
#
# Epoch 3 / 50
# ----------
# Train Loss: 0.8590 Acc: 80.5929 F1: 0.8058 | Val Loss: 0.4599 Acc: 90.3800% F1: 0.9005 | Epoch time: 1m 19s
#
# Epoch 4 / 50
# ----------
# Train Loss: 0.7380 Acc: 82.8365 F1: 0.8280 | Val Loss: 0.3781 Acc: 92.4483% F1: 0.9233 | Epoch time: 1m 19s
#
# Epoch 5 / 50
# ----------
# Train Loss: 0.6333 Acc: 85.1442 F1: 0.8511 | Val Loss: 0.3283 Acc: 93.2660% F1: 0.9330 | Epoch time: 1m 19s
#
# Epoch 6 / 50
# ----------
# Train Loss: 0.5855 Acc: 85.6571 F1: 0.8565 | Val Loss: 0.2988 Acc: 93.6989% F1: 0.9364 | Epoch time: 1m 20s
#
# Epoch 7 / 50
# ----------
# Train Loss: 0.5519 Acc: 86.4423 F1: 0.8641 | Val Loss: 0.2628 Acc: 94.4204% F1: 0.9450 | Epoch time: 1m 19s
#
# Epoch 8 / 50
# ----------
# Train Loss: 0.5076 Acc: 87.8526 F1: 0.8783 | Val Loss: 0.2440 Acc: 94.9014% F1: 0.9491 | Epoch time: 1m 19s
#
# Epoch 9 / 50
# ----------
# Train Loss: 0.4945 Acc: 87.2276 F1: 0.8722 | Val Loss: 0.2459 Acc: 93.6989% F1: 0.9364 | Epoch time: 1m 19s
#
# Epoch 10 / 50
# ----------
# Train Loss: 0.4623 Acc: 87.9647 F1: 0.8794 | Val Loss: 0.2243 Acc: 94.5647% F1: 0.9452 | Epoch time: 1m 19s
#
# Epoch 11 / 50
# ----------
# Train Loss: 0.4388 Acc: 88.7500 F1: 0.8872 | Val Loss: 0.2179 Acc: 94.8052% F1: 0.9484 | Epoch time: 1m 19s
#
# Epoch 12 / 50
# ----------
# Train Loss: 0.4513 Acc: 87.7724 F1: 0.8775 | Val Loss: 0.2161 Acc: 94.5647% F1: 0.9459 | Epoch time: 1m 19s
#
# Epoch 13 / 50
# ----------
# Train Loss: 0.4227 Acc: 88.6859 F1: 0.8865 | Val Loss: 0.2045 Acc: 94.7571% F1: 0.9475 | Epoch time: 1m 18s
#
# Epoch 14 / 50
# ----------
# Train Loss: 0.4040 Acc: 88.9263 F1: 0.8894 | Val Loss: 0.1999 Acc: 95.5748% F1: 0.9558 | Epoch time: 1m 19s
#
# Epoch 15 / 50
# ----------
# Train Loss: 0.4006 Acc: 89.0705 F1: 0.8907 | Val Loss: 0.1852 Acc: 95.6229% F1: 0.9565 | Epoch time: 1m 18s
#
# Epoch 16 / 50
# ----------
# Train Loss: 0.3989 Acc: 88.7660 F1: 0.8874 | Val Loss: 0.1914 Acc: 95.0938% F1: 0.9509 | Epoch time: 1m 19s
#
# Epoch 17 / 50
# ----------
# Train Loss: 0.3839 Acc: 89.0865 F1: 0.8910 | Val Loss: 0.1746 Acc: 95.2381% F1: 0.9523 | Epoch time: 1m 19s
#
# Epoch 18 / 50
# ----------
# Train Loss: 0.3846 Acc: 89.4551 F1: 0.8942 | Val Loss: 0.1816 Acc: 94.8052% F1: 0.9484 | Epoch time: 1m 18s
#
# Epoch 19 / 50
# ----------
# Train Loss: 0.3795 Acc: 89.7596 F1: 0.8973 | Val Loss: 0.1835 Acc: 95.6710% F1: 0.9574 | Epoch time: 1m 19s
#
# Epoch 20 / 50
# ----------
# Train Loss: 0.3515 Acc: 90.4647 F1: 0.9046 | Val Loss: 0.1743 Acc: 95.7191% F1: 0.9566 | Epoch time: 1m 19s
#
# Epoch 21 / 50
# ----------
# Train Loss: 0.3515 Acc: 90.2244 F1: 0.9022 | Val Loss: 0.1710 Acc: 95.9115% F1: 0.9593 | Epoch time: 1m 19s
#
# Epoch 22 / 50
# ----------
# Train Loss: 0.3437 Acc: 90.1763 F1: 0.9016 | Val Loss: 0.1878 Acc: 95.0457% F1: 0.9505 | Epoch time: 1m 20s
#
# Epoch 23 / 50
# ----------
# Train Loss: 0.3479 Acc: 90.1923 F1: 0.9018 | Val Loss: 0.1587 Acc: 95.8153% F1: 0.9586 | Epoch time: 1m 19s
#
# Epoch 24 / 50
# ----------
# Train Loss: 0.3337 Acc: 90.8494 F1: 0.9084 | Val Loss: 0.1725 Acc: 94.9014% F1: 0.9495 | Epoch time: 1m 18s
#
# Epoch 25 / 50
# ----------
# Train Loss: 0.3446 Acc: 89.9519 F1: 0.8995 | Val Loss: 0.1669 Acc: 95.2381% F1: 0.9527 | Epoch time: 1m 19s
#
# Epoch 26 / 50
# ----------
# Train Loss: 0.3381 Acc: 90.6731 F1: 0.9068 | Val Loss: 0.1676 Acc: 95.3343% F1: 0.9534 | Epoch time: 1m 18s
#
# Epoch 27 / 50
# ----------
# Train Loss: 0.3685 Acc: 89.1186 F1: 0.8911 | Val Loss: 0.1684 Acc: 95.5267% F1: 0.9556 | Epoch time: 1m 19s
#
# Epoch 28 / 50
# ----------
# Train Loss: 0.3306 Acc: 90.7692 F1: 0.9074 | Val Loss: 0.1656 Acc: 95.4786% F1: 0.9547 | Epoch time: 1m 19s
#
# Epoch 29 / 50
# ----------
# Train Loss: 0.3243 Acc: 90.2404 F1: 0.9024 | Val Loss: 0.1698 Acc: 95.3824% F1: 0.9546 | Epoch time: 1m 19s
#
# Epoch 30 / 50
# ----------
# Train Loss: 0.3348 Acc: 90.2404 F1: 0.9023 | Val Loss: 0.1579 Acc: 95.6710% F1: 0.9570 | Epoch time: 1m 18s
#
# Epoch 31 / 50
# ----------
# Train Loss: 0.3118 Acc: 90.9936 F1: 0.9098 | Val Loss: 0.1648 Acc: 95.0938% F1: 0.9512 | Epoch time: 1m 19s
#
# Epoch 32 / 50
# ----------
# Train Loss: 0.3144 Acc: 90.8974 F1: 0.9087 | Val Loss: 0.1639 Acc: 95.7672% F1: 0.9578 | Epoch time: 1m 19s
#
# Epoch 33 / 50
# ----------
# Train Loss: 0.3289 Acc: 90.5288 F1: 0.9051 | Val Loss: 0.1777 Acc: 95.3343% F1: 0.9537 | Epoch time: 1m 19s
#
# Epoch 34 / 50
# ----------
# Train Loss: 0.3194 Acc: 91.0577 F1: 0.9105 | Val Loss: 0.1701 Acc: 95.3824% F1: 0.9539 | Epoch time: 1m 19s
#
# Epoch 35 / 50
# ----------
# Train Loss: 0.3243 Acc: 90.8173 F1: 0.9080 | Val Loss: 0.1625 Acc: 95.5748% F1: 0.9558 | Epoch time: 1m 18s
#
# Epoch 36 / 50
# ----------
# Train Loss: 0.3084 Acc: 91.0737 F1: 0.9105 | Val Loss: 0.1530 Acc: 96.1520% F1: 0.9616 | Epoch time: 1m 19s
#
# Epoch 37 / 50
# ----------
# Train Loss: 0.3065 Acc: 90.7853 F1: 0.9078 | Val Loss: 0.1563 Acc: 95.8153% F1: 0.9585 | Epoch time: 1m 19s
#
# Epoch 38 / 50
# ----------
# Train Loss: 0.3134 Acc: 90.7212 F1: 0.9071 | Val Loss: 0.1449 Acc: 96.3925% F1: 0.9639 | Epoch time: 1m 19s
#
# Epoch 39 / 50
# ----------
# Train Loss: 0.3154 Acc: 90.9615 F1: 0.9095 | Val Loss: 0.1619 Acc: 95.6229% F1: 0.9558 | Epoch time: 1m 20s
#
# Epoch 40 / 50
# ----------
# Train Loss: 0.3165 Acc: 90.8173 F1: 0.9080 | Val Loss: 0.1684 Acc: 95.4786% F1: 0.9552 | Epoch time: 1m 19s
#
# Epoch 41 / 50
# ----------
# Train Loss: 0.3063 Acc: 90.8333 F1: 0.9083 | Val Loss: 0.1516 Acc: 95.7191% F1: 0.9573 | Epoch time: 1m 19s
#
# Epoch 42 / 50
# ----------
# Train Loss: 0.3190 Acc: 90.4808 F1: 0.9047 | Val Loss: 0.1541 Acc: 95.8153% F1: 0.9583 | Epoch time: 1m 19s
#
# Epoch 43 / 50
# ----------
# Train Loss: 0.3101 Acc: 90.8654 F1: 0.9085 | Val Loss: 0.1577 Acc: 95.7191% F1: 0.9579 | Epoch time: 1m 20s
#
# Epoch 44 / 50
# ----------
# Train Loss: 0.3241 Acc: 90.7532 F1: 0.9075 | Val Loss: 0.1413 Acc: 96.2001% F1: 0.9622 | Epoch time: 1m 19s
#
# Epoch 45 / 50
# ----------
# Train Loss: 0.3148 Acc: 90.7051 F1: 0.9071 | Val Loss: 0.1518 Acc: 95.8634% F1: 0.9592 | Epoch time: 1m 19s
#
# Epoch 46 / 50
# ----------
# Train Loss: 0.2997 Acc: 91.3782 F1: 0.9136 | Val Loss: 0.1666 Acc: 95.1900% F1: 0.9525 | Epoch time: 1m 19s
#
# Epoch 47 / 50
# ----------
# Train Loss: 0.2941 Acc: 91.5865 F1: 0.9159 | Val Loss: 0.1428 Acc: 96.1039% F1: 0.9614 | Epoch time: 1m 19s
#
# Epoch 48 / 50
# ----------
# Train Loss: 0.2875 Acc: 91.6026 F1: 0.9159 | Val Loss: 0.1497 Acc: 95.9596% F1: 0.9599 | Epoch time: 1m 21s
#
# Epoch 49 / 50
# ----------
# Train Loss: 0.3185 Acc: 90.6731 F1: 0.9065 | Val Loss: 0.1487 Acc: 96.2001% F1: 0.9622 | Epoch time: 1m 19s
#
# Epoch 50 / 50
# ----------
# Train Loss: 0.3098 Acc: 90.7532 F1: 0.9075 | Val Loss: 0.1534 Acc: 95.8634% F1: 0.9587 | Epoch time: 1m 19s
#
# Training DenseNet121 no_hidden complete in 65m 42s
# Best val Acc: 96.392496
# Best val F1: 0.963943
# === Model: DenseNet121 | Skenario: with_hidden ===
#
# Epoch 1 / 50
# ----------
# Train Loss: 2.6666 Acc: 33.8301 F1: 0.3271 | Val Loss: 1.1450 Acc: 75.8538% F1: 0.7373 | Epoch time: 1m 19s
#
# Epoch 2 / 50
# ----------
# Train Loss: 1.3944 Acc: 62.6282 F1: 0.6185 | Val Loss: 0.5951 Acc: 87.1573% F1: 0.8687 | Epoch time: 1m 19s
#
# Epoch 3 / 50
# ----------
# Train Loss: 1.0940 Acc: 69.5353 F1: 0.6917 | Val Loss: 0.4521 Acc: 89.5623% F1: 0.8936 | Epoch time: 1m 19s
#
# Epoch 4 / 50
# ----------
# Train Loss: 0.9463 Acc: 73.6218 F1: 0.7343 | Val Loss: 0.3681 Acc: 91.2458% F1: 0.9120 | Epoch time: 1m 21s
#
# Epoch 5 / 50
# ----------
# Train Loss: 0.8863 Acc: 74.6154 F1: 0.7442 | Val Loss: 0.3326 Acc: 91.2458% F1: 0.9128 | Epoch time: 1m 19s
#
# Epoch 6 / 50
# ----------
# Train Loss: 0.8551 Acc: 75.6891 F1: 0.7554 | Val Loss: 0.2857 Acc: 92.9774% F1: 0.9301 | Epoch time: 1m 19s
#
# Epoch 7 / 50
# ----------
# Train Loss: 0.7832 Acc: 77.4359 F1: 0.7727 | Val Loss: 0.3011 Acc: 92.2559% F1: 0.9208 | Epoch time: 1m 19s
#
# Epoch 8 / 50
# ----------
# Train Loss: 0.7900 Acc: 77.6122 F1: 0.7751 | Val Loss: 0.2562 Acc: 92.9293% F1: 0.9294 | Epoch time: 1m 19s
#
# Epoch 9 / 50
# ----------
# Train Loss: 0.7084 Acc: 79.0064 F1: 0.7890 | Val Loss: 0.2290 Acc: 94.1799% F1: 0.9414 | Epoch time: 1m 19s
#
# Epoch 10 / 50
# ----------
# Train Loss: 0.7069 Acc: 79.4551 F1: 0.7933 | Val Loss: 0.2357 Acc: 93.6508% F1: 0.9368 | Epoch time: 1m 19s
#
# Epoch 11 / 50
# ----------
# Train Loss: 0.7066 Acc: 78.8942 F1: 0.7883 | Val Loss: 0.2155 Acc: 93.8913% F1: 0.9392 | Epoch time: 1m 19s
#
# Epoch 12 / 50
# ----------
# Train Loss: 0.6823 Acc: 79.3109 F1: 0.7921 | Val Loss: 0.2082 Acc: 93.7470% F1: 0.9373 | Epoch time: 1m 19s
#
# Epoch 13 / 50
# ----------
# Train Loss: 0.6879 Acc: 79.5513 F1: 0.7944 | Val Loss: 0.2128 Acc: 94.0356% F1: 0.9416 | Epoch time: 1m 19s
#
# Epoch 14 / 50
# ----------
# Train Loss: 0.6601 Acc: 80.5769 F1: 0.8047 | Val Loss: 0.2082 Acc: 93.8432% F1: 0.9383 | Epoch time: 1m 19s
#
# Epoch 15 / 50
# ----------
# Train Loss: 0.6725 Acc: 79.9519 F1: 0.7985 | Val Loss: 0.1919 Acc: 94.4685% F1: 0.9454 | Epoch time: 1m 20s
#
# Epoch 16 / 50
# ----------
# Train Loss: 0.6586 Acc: 80.8494 F1: 0.8079 | Val Loss: 0.1956 Acc: 94.6609% F1: 0.9463 | Epoch time: 1m 19s
#
# Epoch 17 / 50
# ----------
# Train Loss: 0.6318 Acc: 81.1378 F1: 0.8105 | Val Loss: 0.2045 Acc: 94.7571% F1: 0.9485 | Epoch time: 1m 19s
#
# Epoch 18 / 50
# ----------
# Train Loss: 0.6314 Acc: 81.4583 F1: 0.8139 | Val Loss: 0.1838 Acc: 94.9495% F1: 0.9498 | Epoch time: 1m 19s
#
# Epoch 19 / 50
# ----------
# Train Loss: 0.6122 Acc: 82.2115 F1: 0.8213 | Val Loss: 0.1824 Acc: 94.9495% F1: 0.9496 | Epoch time: 1m 19s
#
# Epoch 20 / 50
# ----------
# Train Loss: 0.6099 Acc: 81.8910 F1: 0.8183 | Val Loss: 0.1815 Acc: 94.8052% F1: 0.9485 | Epoch time: 1m 19s
#
# Epoch 21 / 50
# ----------
# Train Loss: 0.5889 Acc: 82.5962 F1: 0.8252 | Val Loss: 0.1774 Acc: 95.3343% F1: 0.9536 | Epoch time: 1m 19s
#
# Epoch 22 / 50
# ----------
# Train Loss: 0.5937 Acc: 82.2756 F1: 0.8223 | Val Loss: 0.1650 Acc: 95.6229% F1: 0.9563 | Epoch time: 1m 19s
#
# Epoch 23 / 50
# ----------
# Train Loss: 0.5906 Acc: 82.6603 F1: 0.8257 | Val Loss: 0.1561 Acc: 95.8153% F1: 0.9580 | Epoch time: 1m 19s
#
# Epoch 24 / 50
# ----------
# Train Loss: 0.5899 Acc: 82.3397 F1: 0.8229 | Val Loss: 0.1687 Acc: 95.1419% F1: 0.9512 | Epoch time: 1m 19s
#
# Epoch 25 / 50
# ----------
# Train Loss: 0.5971 Acc: 82.4679 F1: 0.8236 | Val Loss: 0.1769 Acc: 95.3824% F1: 0.9544 | Epoch time: 1m 19s
#
# Epoch 26 / 50
# ----------
# Train Loss: 0.6029 Acc: 82.3878 F1: 0.8231 | Val Loss: 0.1763 Acc: 94.7571% F1: 0.9477 | Epoch time: 1m 19s
#
# Epoch 27 / 50
# ----------
# Train Loss: 0.6085 Acc: 82.5160 F1: 0.8248 | Val Loss: 0.1816 Acc: 94.1318% F1: 0.9409 | Epoch time: 1m 19s
#
# Epoch 28 / 50
# ----------
# Train Loss: 0.5757 Acc: 83.0769 F1: 0.8301 | Val Loss: 0.1619 Acc: 95.4305% F1: 0.9544 | Epoch time: 1m 19s
#
# Epoch 29 / 50
# ----------
# Train Loss: 0.5649 Acc: 83.0609 F1: 0.8301 | Val Loss: 0.1671 Acc: 95.0938% F1: 0.9509 | Epoch time: 1m 19s
#
# Epoch 30 / 50
# ----------
# Train Loss: 0.5917 Acc: 82.1955 F1: 0.8215 | Val Loss: 0.1637 Acc: 95.8153% F1: 0.9582 | Epoch time: 1m 19s
#
# Epoch 31 / 50
# ----------
# Train Loss: 0.5540 Acc: 82.9006 F1: 0.8282 | Val Loss: 0.1547 Acc: 95.2862% F1: 0.9524 | Epoch time: 1m 19s
#
# Epoch 32 / 50
# ----------
# Train Loss: 0.5715 Acc: 83.1891 F1: 0.8314 | Val Loss: 0.1564 Acc: 95.2862% F1: 0.9527 | Epoch time: 1m 19s
#
# Epoch 33 / 50
# ----------
# Train Loss: 0.5776 Acc: 82.4038 F1: 0.8233 | Val Loss: 0.1833 Acc: 94.8533% F1: 0.9487 | Epoch time: 1m 19s
#
# Epoch 34 / 50
# ----------
# Train Loss: 0.5738 Acc: 82.6442 F1: 0.8261 | Val Loss: 0.1700 Acc: 95.2862% F1: 0.9530 | Epoch time: 1m 19s
#
# Epoch 35 / 50
# ----------
# Train Loss: 0.5468 Acc: 83.8141 F1: 0.8378 | Val Loss: 0.1889 Acc: 94.3723% F1: 0.9441 | Epoch time: 1m 19s
#
# Epoch 36 / 50
# ----------
# Train Loss: 0.5744 Acc: 83.1731 F1: 0.8313 | Val Loss: 0.1575 Acc: 95.7191% F1: 0.9575 | Epoch time: 1m 19s
#
# Epoch 37 / 50
# ----------
# Train Loss: 0.5014 Acc: 84.9359 F1: 0.8487 | Val Loss: 0.1619 Acc: 95.9115% F1: 0.9592 | Epoch time: 1m 19s
#
# Epoch 38 / 50
# ----------
# Train Loss: 0.5786 Acc: 83.1891 F1: 0.8320 | Val Loss: 0.1599 Acc: 95.4786% F1: 0.9548 | Epoch time: 1m 19s
#
# Epoch 39 / 50
# ----------
# Train Loss: 0.5433 Acc: 84.5513 F1: 0.8449 | Val Loss: 0.1516 Acc: 95.7672% F1: 0.9580 | Epoch time: 1m 19s
#
# Epoch 40 / 50
# ----------
# Train Loss: 0.5473 Acc: 83.7340 F1: 0.8368 | Val Loss: 0.1473 Acc: 96.0558% F1: 0.9608 | Epoch time: 1m 19s
#
# Epoch 41 / 50
# ----------
# Train Loss: 0.5576 Acc: 83.9103 F1: 0.8389 | Val Loss: 0.1506 Acc: 96.2001% F1: 0.9619 | Epoch time: 1m 19s
#
# Epoch 42 / 50
# ----------
# Train Loss: 0.5699 Acc: 82.9968 F1: 0.8294 | Val Loss: 0.1597 Acc: 95.8153% F1: 0.9579 | Epoch time: 1m 19s
#
# Epoch 43 / 50
# ----------
# Train Loss: 0.5721 Acc: 83.1571 F1: 0.8308 | Val Loss: 0.1429 Acc: 95.9115% F1: 0.9591 | Epoch time: 1m 19s
#
# Epoch 44 / 50
# ----------
# Train Loss: 0.5750 Acc: 83.0128 F1: 0.8297 | Val Loss: 0.1424 Acc: 96.2963% F1: 0.9631 | Epoch time: 1m 19s
#
# Epoch 45 / 50
# ----------
# Train Loss: 0.5478 Acc: 83.6859 F1: 0.8362 | Val Loss: 0.1397 Acc: 96.2001% F1: 0.9624 | Epoch time: 1m 19s
#
# Epoch 46 / 50
# ----------
# Train Loss: 0.5477 Acc: 83.9423 F1: 0.8392 | Val Loss: 0.1435 Acc: 96.1520% F1: 0.9619 | Epoch time: 1m 20s
#
# Epoch 47 / 50
# ----------
# Train Loss: 0.5796 Acc: 82.8526 F1: 0.8280 | Val Loss: 0.1621 Acc: 95.4786% F1: 0.9551 | Epoch time: 1m 19s
#
# Epoch 48 / 50
# ----------
# Train Loss: 0.5216 Acc: 84.3590 F1: 0.8434 | Val Loss: 0.1614 Acc: 96.0077% F1: 0.9605 | Epoch time: 1m 19s
#
# Epoch 49 / 50
# ----------
# Train Loss: 0.5387 Acc: 84.0385 F1: 0.8401 | Val Loss: 0.1512 Acc: 96.1039% F1: 0.9613 | Epoch time: 1m 19s
#
# Epoch 50 / 50
# ----------
# Train Loss: 0.5242 Acc: 84.4071 F1: 0.8433 | Val Loss: 0.1609 Acc: 95.6229% F1: 0.9565 | Epoch time: 1m 19s
#
# Training DenseNet121 with_hidden complete in 65m 49s
# Best val Acc: 96.296296
# Best val F1: 0.963088

# %%
# MobileNetV3 Large
#Tanpa Hidden Layer
model = initialize_model('MobileNetV3', 'no_hidden')
res = train_model(model, 'MobileNetV3', 'no_hidden')
results_training.append(res)

#Dengan Hidden Layer
model = initialize_model('MobileNetV3', 'with_hidden')
res = train_model(model, 'MobileNetV3', 'with_hidden')
results_training.append(res)
# Out:
# === Model: MobileNetV3 | Skenario: no_hidden ===
#
# Epoch 1 / 50
# ----------
# Train Loss: 1.3138 Acc: 65.9135 F1: 0.6569 | Val Loss: 0.3751 Acc: 89.1294% F1: 0.8892 | Epoch time: 0m 48s
#
# Epoch 2 / 50
# ----------
# Train Loss: 0.6499 Acc: 81.6827 F1: 0.8161 | Val Loss: 0.2775 Acc: 91.9673% F1: 0.9179 | Epoch time: 0m 48s
#
# Epoch 3 / 50
# ----------
# Train Loss: 0.5357 Acc: 83.8782 F1: 0.8381 | Val Loss: 0.2299 Acc: 93.5065% F1: 0.9362 | Epoch time: 0m 48s
#
# Epoch 4 / 50
# ----------
# Train Loss: 0.4965 Acc: 85.3686 F1: 0.8534 | Val Loss: 0.2093 Acc: 93.7951% F1: 0.9377 | Epoch time: 0m 48s
#
# Epoch 5 / 50
# ----------
# Train Loss: 0.4550 Acc: 86.2019 F1: 0.8619 | Val Loss: 0.1789 Acc: 94.5166% F1: 0.9452 | Epoch time: 0m 48s
#
# Epoch 6 / 50
# ----------
# Train Loss: 0.4271 Acc: 87.3558 F1: 0.8733 | Val Loss: 0.2615 Acc: 92.3040% F1: 0.9241 | Epoch time: 0m 48s
#
# Epoch 7 / 50
# ----------
# Train Loss: 0.4062 Acc: 87.8686 F1: 0.8785 | Val Loss: 0.1649 Acc: 95.5748% F1: 0.9559 | Epoch time: 0m 48s
#
# Epoch 8 / 50
# ----------
# Train Loss: 0.3857 Acc: 88.5897 F1: 0.8858 | Val Loss: 0.1610 Acc: 94.9495% F1: 0.9495 | Epoch time: 0m 48s
#
# Epoch 9 / 50
# ----------
# Train Loss: 0.3666 Acc: 89.2308 F1: 0.8922 | Val Loss: 0.1825 Acc: 95.0457% F1: 0.9511 | Epoch time: 0m 48s
#
# Epoch 10 / 50
# ----------
# Train Loss: 0.3817 Acc: 88.7660 F1: 0.8874 | Val Loss: 0.1696 Acc: 95.2381% F1: 0.9524 | Epoch time: 0m 48s
#
# Epoch 11 / 50
# ----------
# Train Loss: 0.3659 Acc: 88.9103 F1: 0.8890 | Val Loss: 0.1735 Acc: 95.0457% F1: 0.9501 | Epoch time: 0m 49s
#
# Epoch 12 / 50
# ----------
# Train Loss: 0.3390 Acc: 89.8558 F1: 0.8985 | Val Loss: 0.1551 Acc: 95.5748% F1: 0.9556 | Epoch time: 0m 48s
#
# Epoch 13 / 50
# ----------
# Train Loss: 0.3287 Acc: 90.0321 F1: 0.9001 | Val Loss: 0.1703 Acc: 95.2862% F1: 0.9530 | Epoch time: 0m 48s
#
# Epoch 14 / 50
# ----------
# Train Loss: 0.3381 Acc: 89.7276 F1: 0.8971 | Val Loss: 0.1623 Acc: 95.9115% F1: 0.9589 | Epoch time: 0m 48s
#
# Epoch 15 / 50
# ----------
# Train Loss: 0.3259 Acc: 90.3526 F1: 0.9034 | Val Loss: 0.1556 Acc: 95.7191% F1: 0.9574 | Epoch time: 0m 48s
#
# Epoch 16 / 50
# ----------
# Train Loss: 0.3181 Acc: 90.3686 F1: 0.9037 | Val Loss: 0.1929 Acc: 94.9495% F1: 0.9490 | Epoch time: 0m 48s
#
# Epoch 17 / 50
# ----------
# Train Loss: 0.3405 Acc: 90.1122 F1: 0.9011 | Val Loss: 0.1711 Acc: 95.1900% F1: 0.9525 | Epoch time: 0m 48s
#
# Epoch 18 / 50
# ----------
# Train Loss: 0.3307 Acc: 90.2564 F1: 0.9025 | Val Loss: 0.1975 Acc: 94.4204% F1: 0.9450 | Epoch time: 0m 48s
#
# Epoch 19 / 50
# ----------
# Train Loss: 0.3352 Acc: 90.0481 F1: 0.9003 | Val Loss: 0.1673 Acc: 95.7191% F1: 0.9574 | Epoch time: 0m 48s
#
# Epoch 20 / 50
# ----------
# Train Loss: 0.2976 Acc: 91.2019 F1: 0.9121 | Val Loss: 0.1876 Acc: 95.1419% F1: 0.9514 | Epoch time: 0m 48s
#
# Epoch 21 / 50
# ----------
# Train Loss: 0.2926 Acc: 91.3462 F1: 0.9134 | Val Loss: 0.1571 Acc: 95.6710% F1: 0.9562 | Epoch time: 0m 48s
#
# Epoch 22 / 50
# ----------
# Train Loss: 0.2992 Acc: 91.2660 F1: 0.9126 | Val Loss: 0.1292 Acc: 96.5849% F1: 0.9658 | Epoch time: 0m 48s
#
# Epoch 23 / 50
# ----------
# Train Loss: 0.3027 Acc: 90.8654 F1: 0.9088 | Val Loss: 0.1422 Acc: 96.2963% F1: 0.9629 | Epoch time: 0m 48s
#
# Epoch 24 / 50
# ----------
# Train Loss: 0.3271 Acc: 90.4647 F1: 0.9044 | Val Loss: 0.1232 Acc: 96.5849% F1: 0.9658 | Epoch time: 0m 48s
#
# Epoch 25 / 50
# ----------
# Train Loss: 0.3004 Acc: 91.5224 F1: 0.9150 | Val Loss: 0.1754 Acc: 95.1419% F1: 0.9511 | Epoch time: 0m 48s
#
# Epoch 26 / 50
# ----------
# Train Loss: 0.3063 Acc: 90.9455 F1: 0.9094 | Val Loss: 0.1377 Acc: 96.1520% F1: 0.9615 | Epoch time: 0m 48s
#
# Epoch 27 / 50
# ----------
# Train Loss: 0.2959 Acc: 91.3141 F1: 0.9129 | Val Loss: 0.1189 Acc: 96.4406% F1: 0.9643 | Epoch time: 0m 48s
#
# Epoch 28 / 50
# ----------
# Train Loss: 0.2752 Acc: 91.7949 F1: 0.9178 | Val Loss: 0.1393 Acc: 96.2963% F1: 0.9630 | Epoch time: 0m 48s
#
# Epoch 29 / 50
# ----------
# Train Loss: 0.2877 Acc: 91.6346 F1: 0.9163 | Val Loss: 0.1847 Acc: 95.8153% F1: 0.9582 | Epoch time: 0m 48s
#
# Epoch 30 / 50
# ----------
# Train Loss: 0.2702 Acc: 92.0994 F1: 0.9208 | Val Loss: 0.1459 Acc: 96.1039% F1: 0.9611 | Epoch time: 0m 48s
#
# Epoch 31 / 50
# ----------
# Train Loss: 0.2967 Acc: 91.4583 F1: 0.9145 | Val Loss: 0.1497 Acc: 96.0558% F1: 0.9606 | Epoch time: 0m 48s
#
# Epoch 32 / 50
# ----------
# Train Loss: 0.2930 Acc: 91.5545 F1: 0.9153 | Val Loss: 0.1564 Acc: 96.4406% F1: 0.9647 | Epoch time: 0m 48s
#
# Epoch 33 / 50
# ----------
# Train Loss: 0.2904 Acc: 91.7628 F1: 0.9176 | Val Loss: 0.1492 Acc: 96.7773% F1: 0.9677 | Epoch time: 0m 48s
#
# Epoch 34 / 50
# ----------
# Train Loss: 0.2991 Acc: 91.4263 F1: 0.9142 | Val Loss: 0.1625 Acc: 96.5849% F1: 0.9660 | Epoch time: 0m 48s
#
# Epoch 35 / 50
# ----------
# Train Loss: 0.3063 Acc: 91.2019 F1: 0.9119 | Val Loss: 0.1736 Acc: 96.2482% F1: 0.9626 | Epoch time: 0m 48s
#
# Epoch 36 / 50
# ----------
# Train Loss: 0.2749 Acc: 92.1314 F1: 0.9212 | Val Loss: 0.1626 Acc: 95.9596% F1: 0.9595 | Epoch time: 0m 48s
#
# Epoch 37 / 50
# ----------
# Train Loss: 0.2580 Acc: 92.6282 F1: 0.9264 | Val Loss: 0.1702 Acc: 95.9115% F1: 0.9592 | Epoch time: 0m 48s
#
# Epoch 38 / 50
# ----------
# Train Loss: 0.2833 Acc: 92.0994 F1: 0.9209 | Val Loss: 0.1474 Acc: 96.7773% F1: 0.9681 | Epoch time: 0m 48s
#
# Epoch 39 / 50
# ----------
# Train Loss: 0.2572 Acc: 92.6923 F1: 0.9269 | Val Loss: 0.1386 Acc: 96.7292% F1: 0.9676 | Epoch time: 0m 48s
#
# Epoch 40 / 50
# ----------
# Train Loss: 0.2870 Acc: 91.9071 F1: 0.9191 | Val Loss: 0.1620 Acc: 96.2001% F1: 0.9623 | Epoch time: 0m 48s
#
# Epoch 41 / 50
# ----------
# Train Loss: 0.2803 Acc: 91.9391 F1: 0.9193 | Val Loss: 0.1838 Acc: 95.6229% F1: 0.9560 | Epoch time: 0m 48s
#
# Epoch 42 / 50
# ----------
# Train Loss: 0.2495 Acc: 92.9006 F1: 0.9290 | Val Loss: 0.1488 Acc: 96.7773% F1: 0.9679 | Epoch time: 0m 48s
#
# Epoch 43 / 50
# ----------
# Train Loss: 0.2852 Acc: 91.8269 F1: 0.9183 | Val Loss: 0.1495 Acc: 95.7672% F1: 0.9579 | Epoch time: 0m 48s
#
# Epoch 44 / 50
# ----------
# Train Loss: 0.2518 Acc: 92.4359 F1: 0.9243 | Val Loss: 0.1667 Acc: 96.4406% F1: 0.9647 | Epoch time: 0m 48s
#
# Epoch 45 / 50
# ----------
# Train Loss: 0.2777 Acc: 92.1955 F1: 0.9220 | Val Loss: 0.1140 Acc: 96.9697% F1: 0.9696 | Epoch time: 0m 48s
#
# Epoch 46 / 50
# ----------
# Train Loss: 0.2707 Acc: 92.1474 F1: 0.9214 | Val Loss: 0.1436 Acc: 96.7773% F1: 0.9678 | Epoch time: 0m 48s
#
# Epoch 47 / 50
# ----------
# Train Loss: 0.2779 Acc: 91.9872 F1: 0.9198 | Val Loss: 0.1455 Acc: 96.6811% F1: 0.9668 | Epoch time: 0m 48s
#
# Epoch 48 / 50
# ----------
# Train Loss: 0.2783 Acc: 91.9872 F1: 0.9199 | Val Loss: 0.1886 Acc: 95.7191% F1: 0.9569 | Epoch time: 0m 48s
#
# Epoch 49 / 50
# ----------
# Train Loss: 0.2654 Acc: 92.4679 F1: 0.9247 | Val Loss: 0.1410 Acc: 96.4406% F1: 0.9648 | Epoch time: 0m 48s
#
# Epoch 50 / 50
# ----------
# Train Loss: 0.2741 Acc: 92.1474 F1: 0.9214 | Val Loss: 0.1646 Acc: 96.2482% F1: 0.9623 | Epoch time: 0m 48s
#
# Training MobileNetV3 no_hidden complete in 39m 53s
# Best val Acc: 96.969697
# Best val F1: 0.969642
# === Model: MobileNetV3 | Skenario: with_hidden ===
#
# Epoch 1 / 50
# ----------
# Train Loss: 1.5557 Acc: 59.1667 F1: 0.5867 | Val Loss: 0.3843 Acc: 88.7446% F1: 0.8845 | Epoch time: 0m 48s
#
# Epoch 2 / 50
# ----------
# Train Loss: 0.7857 Acc: 77.2436 F1: 0.7711 | Val Loss: 0.3270 Acc: 90.5243% F1: 0.9040 | Epoch time: 0m 48s
#
# Epoch 3 / 50
# ----------
# Train Loss: 0.6664 Acc: 80.2564 F1: 0.8018 | Val Loss: 0.2278 Acc: 93.5546% F1: 0.9352 | Epoch time: 0m 48s
#
# Epoch 4 / 50
# ----------
# Train Loss: 0.5940 Acc: 82.4359 F1: 0.8237 | Val Loss: 0.2489 Acc: 91.9673% F1: 0.9175 | Epoch time: 0m 48s
#
# Epoch 5 / 50
# ----------
# Train Loss: 0.5533 Acc: 83.0288 F1: 0.8298 | Val Loss: 0.1964 Acc: 93.7470% F1: 0.9370 | Epoch time: 0m 48s
#
# Epoch 6 / 50
# ----------
# Train Loss: 0.5275 Acc: 84.4071 F1: 0.8438 | Val Loss: 0.2038 Acc: 94.5166% F1: 0.9450 | Epoch time: 0m 48s
#
# Epoch 7 / 50
# ----------
# Train Loss: 0.5215 Acc: 84.9199 F1: 0.8490 | Val Loss: 0.2222 Acc: 93.9875% F1: 0.9381 | Epoch time: 0m 48s
#
# Epoch 8 / 50
# ----------
# Train Loss: 0.4679 Acc: 86.0256 F1: 0.8601 | Val Loss: 0.2056 Acc: 94.0837% F1: 0.9401 | Epoch time: 0m 48s
#
# Epoch 9 / 50
# ----------
# Train Loss: 0.4991 Acc: 85.4006 F1: 0.8540 | Val Loss: 0.2015 Acc: 93.4584% F1: 0.9352 | Epoch time: 0m 48s
#
# Epoch 10 / 50
# ----------
# Train Loss: 0.4689 Acc: 86.1699 F1: 0.8615 | Val Loss: 0.1758 Acc: 94.8533% F1: 0.9484 | Epoch time: 0m 48s
#
# Epoch 11 / 50
# ----------
# Train Loss: 0.4751 Acc: 86.4744 F1: 0.8645 | Val Loss: 0.1432 Acc: 95.6229% F1: 0.9562 | Epoch time: 0m 48s
#
# Epoch 12 / 50
# ----------
# Train Loss: 0.4331 Acc: 87.7244 F1: 0.8772 | Val Loss: 0.1570 Acc: 95.0457% F1: 0.9510 | Epoch time: 0m 48s
#
# Epoch 13 / 50
# ----------
# Train Loss: 0.4556 Acc: 87.1154 F1: 0.8709 | Val Loss: 0.2014 Acc: 94.5166% F1: 0.9451 | Epoch time: 0m 48s
#
# Epoch 14 / 50
# ----------
# Train Loss: 0.4506 Acc: 87.2276 F1: 0.8722 | Val Loss: 0.2049 Acc: 94.1318% F1: 0.9424 | Epoch time: 0m 48s
#
# Epoch 15 / 50
# ----------
# Train Loss: 0.4583 Acc: 86.7147 F1: 0.8671 | Val Loss: 0.1671 Acc: 95.0457% F1: 0.9506 | Epoch time: 0m 48s
#
# Epoch 16 / 50
# ----------
# Train Loss: 0.4083 Acc: 88.6058 F1: 0.8859 | Val Loss: 0.1757 Acc: 95.0457% F1: 0.9503 | Epoch time: 0m 48s
#
# Epoch 17 / 50
# ----------
# Train Loss: 0.4470 Acc: 87.6603 F1: 0.8766 | Val Loss: 0.1719 Acc: 95.2381% F1: 0.9524 | Epoch time: 0m 48s
#
# Epoch 18 / 50
# ----------
# Train Loss: 0.4378 Acc: 87.5481 F1: 0.8751 | Val Loss: 0.1578 Acc: 95.6229% F1: 0.9560 | Epoch time: 0m 48s
#
# Epoch 19 / 50
# ----------
# Train Loss: 0.4234 Acc: 87.8526 F1: 0.8786 | Val Loss: 0.1530 Acc: 95.7191% F1: 0.9572 | Epoch time: 0m 48s
#
# Epoch 20 / 50
# ----------
# Train Loss: 0.4172 Acc: 88.3974 F1: 0.8839 | Val Loss: 0.1498 Acc: 96.0077% F1: 0.9602 | Epoch time: 0m 48s
#
# Epoch 21 / 50
# ----------
# Train Loss: 0.4145 Acc: 88.3173 F1: 0.8832 | Val Loss: 0.1831 Acc: 94.7090% F1: 0.9468 | Epoch time: 0m 48s
#
# Epoch 22 / 50
# ----------
# Train Loss: 0.4119 Acc: 88.4776 F1: 0.8845 | Val Loss: 0.1422 Acc: 95.7191% F1: 0.9570 | Epoch time: 0m 48s
#
# Epoch 23 / 50
# ----------
# Train Loss: 0.4143 Acc: 88.6218 F1: 0.8861 | Val Loss: 0.1654 Acc: 95.4305% F1: 0.9544 | Epoch time: 0m 49s
#
# Epoch 24 / 50
# ----------
# Train Loss: 0.3980 Acc: 88.9904 F1: 0.8897 | Val Loss: 0.1376 Acc: 96.0077% F1: 0.9600 | Epoch time: 0m 48s
#
# Epoch 25 / 50
# ----------
# Train Loss: 0.3939 Acc: 89.0545 F1: 0.8904 | Val Loss: 0.1591 Acc: 95.7191% F1: 0.9571 | Epoch time: 0m 48s
#
# Epoch 26 / 50
# ----------
# Train Loss: 0.4010 Acc: 89.1987 F1: 0.8918 | Val Loss: 0.1549 Acc: 96.1520% F1: 0.9619 | Epoch time: 0m 48s
#
# Epoch 27 / 50
# ----------
# Train Loss: 0.3890 Acc: 89.1186 F1: 0.8911 | Val Loss: 0.1745 Acc: 95.5748% F1: 0.9558 | Epoch time: 0m 48s
#
# Epoch 28 / 50
# ----------
# Train Loss: 0.3934 Acc: 88.8141 F1: 0.8879 | Val Loss: 0.1833 Acc: 95.6229% F1: 0.9559 | Epoch time: 0m 48s
#
# Epoch 29 / 50
# ----------
# Train Loss: 0.4088 Acc: 88.8942 F1: 0.8888 | Val Loss: 0.1362 Acc: 96.4887% F1: 0.9648 | Epoch time: 0m 48s
#
# Epoch 30 / 50
# ----------
# Train Loss: 0.3722 Acc: 90.0481 F1: 0.9005 | Val Loss: 0.1442 Acc: 96.7773% F1: 0.9678 | Epoch time: 0m 48s
#
# Epoch 31 / 50
# ----------
# Train Loss: 0.3817 Acc: 89.6795 F1: 0.8966 | Val Loss: 0.1681 Acc: 95.3824% F1: 0.9538 | Epoch time: 0m 48s
#
# Epoch 32 / 50
# ----------
# Train Loss: 0.4071 Acc: 89.4872 F1: 0.8949 | Val Loss: 0.1565 Acc: 95.3824% F1: 0.9540 | Epoch time: 0m 48s
#
# Epoch 33 / 50
# ----------
# Train Loss: 0.4147 Acc: 88.9744 F1: 0.8896 | Val Loss: 0.1473 Acc: 95.8634% F1: 0.9586 | Epoch time: 0m 48s
#
# Epoch 34 / 50
# ----------
# Train Loss: 0.3743 Acc: 89.6474 F1: 0.8964 | Val Loss: 0.1515 Acc: 95.9115% F1: 0.9588 | Epoch time: 0m 48s
#
# Epoch 35 / 50
# ----------
# Train Loss: 0.3742 Acc: 89.6314 F1: 0.8963 | Val Loss: 0.1413 Acc: 96.6811% F1: 0.9667 | Epoch time: 0m 48s
#
# Epoch 36 / 50
# ----------
# Train Loss: 0.4084 Acc: 89.0865 F1: 0.8909 | Val Loss: 0.1511 Acc: 96.3925% F1: 0.9640 | Epoch time: 0m 48s
#
# Epoch 37 / 50
# ----------
# Train Loss: 0.3602 Acc: 90.2404 F1: 0.9023 | Val Loss: 0.1565 Acc: 95.8153% F1: 0.9581 | Epoch time: 0m 48s
#
# Epoch 38 / 50
# ----------
# Train Loss: 0.3734 Acc: 89.6474 F1: 0.8965 | Val Loss: 0.1288 Acc: 96.2482% F1: 0.9627 | Epoch time: 0m 48s
#
# Epoch 39 / 50
# ----------
# Train Loss: 0.3756 Acc: 89.6955 F1: 0.8970 | Val Loss: 0.1530 Acc: 96.4406% F1: 0.9643 | Epoch time: 0m 48s
#
# Epoch 40 / 50
# ----------
# Train Loss: 0.3860 Acc: 89.7276 F1: 0.8971 | Val Loss: 0.1483 Acc: 96.4406% F1: 0.9644 | Epoch time: 0m 48s
#
# Epoch 41 / 50
# ----------
# Train Loss: 0.3642 Acc: 90.0641 F1: 0.9007 | Val Loss: 0.1596 Acc: 96.4406% F1: 0.9643 | Epoch time: 0m 48s
#
# Epoch 42 / 50
# ----------
# Train Loss: 0.3917 Acc: 90.1603 F1: 0.9013 | Val Loss: 0.1353 Acc: 96.2482% F1: 0.9624 | Epoch time: 0m 48s
#
# Epoch 43 / 50
# ----------
# Train Loss: 0.3880 Acc: 89.8397 F1: 0.8983 | Val Loss: 0.1260 Acc: 96.7292% F1: 0.9671 | Epoch time: 0m 48s
#
# Epoch 44 / 50
# ----------
# Train Loss: 0.3935 Acc: 89.8718 F1: 0.8985 | Val Loss: 0.1310 Acc: 96.5368% F1: 0.9653 | Epoch time: 0m 48s
#
# Epoch 45 / 50
# ----------
# Train Loss: 0.3708 Acc: 90.2083 F1: 0.9020 | Val Loss: 0.1326 Acc: 97.0178% F1: 0.9702 | Epoch time: 0m 48s
#
# Epoch 46 / 50
# ----------
# Train Loss: 0.3781 Acc: 90.3526 F1: 0.9034 | Val Loss: 0.1683 Acc: 96.4887% F1: 0.9648 | Epoch time: 0m 49s
#
# Epoch 47 / 50
# ----------
# Train Loss: 0.4019 Acc: 89.6955 F1: 0.8970 | Val Loss: 0.1336 Acc: 96.8735% F1: 0.9686 | Epoch time: 0m 48s
#
# Epoch 48 / 50
# ----------
# Train Loss: 0.4030 Acc: 89.6314 F1: 0.8962 | Val Loss: 0.1370 Acc: 96.7292% F1: 0.9671 | Epoch time: 0m 48s
#
# Epoch 49 / 50
# ----------
# Train Loss: 0.3769 Acc: 90.0321 F1: 0.9003 | Val Loss: 0.1346 Acc: 96.6330% F1: 0.9661 | Epoch time: 0m 48s
#
# Epoch 50 / 50
# ----------
# Train Loss: 0.3862 Acc: 90.2885 F1: 0.9029 | Val Loss: 0.1628 Acc: 96.0558% F1: 0.9608 | Epoch time: 0m 48s
#
# Training MobileNetV3 with_hidden complete in 39m 55s
# Best val Acc: 97.017797
# Best val F1: 0.970206

# %%
# ConvNeXt Tiny
#Tanpa Hidden Layer
model = initialize_model('ConvNeXt', 'no_hidden')
res = train_model(model, 'ConvNeXt', 'no_hidden')
results_training.append(res)

#Dengan Hidden Layer
model = initialize_model('ConvNeXt', 'with_hidden')
res = train_model(model, 'ConvNeXt', 'with_hidden')
results_training.append(res)
# Out:
# === Model: ConvNeXt | Skenario: no_hidden ===
#
# Epoch 1 / 50
# ----------
# Train Loss: 1.4495 Acc: 69.3750 F1: 0.6917 | Val Loss: 0.4281 Acc: 91.3901% F1: 0.9131 | Epoch time: 1m 36s
#
# Epoch 2 / 50
# ----------
# Train Loss: 0.5478 Acc: 87.3558 F1: 0.8736 | Val Loss: 0.2524 Acc: 94.1318% F1: 0.9411 | Epoch time: 1m 36s
#
# Epoch 3 / 50
# ----------
# Train Loss: 0.3908 Acc: 90.1122 F1: 0.9011 | Val Loss: 0.1988 Acc: 95.0457% F1: 0.9508 | Epoch time: 1m 36s
#
# Epoch 4 / 50
# ----------
# Train Loss: 0.3218 Acc: 92.2596 F1: 0.9227 | Val Loss: 0.1612 Acc: 96.2963% F1: 0.9631 | Epoch time: 1m 36s
#
# Epoch 5 / 50
# ----------
# Train Loss: 0.2793 Acc: 92.8045 F1: 0.9281 | Val Loss: 0.1458 Acc: 96.4887% F1: 0.9647 | Epoch time: 1m 36s
#
# Epoch 6 / 50
# ----------
# Train Loss: 0.2448 Acc: 93.5256 F1: 0.9353 | Val Loss: 0.1263 Acc: 97.1140% F1: 0.9714 | Epoch time: 1m 36s
#
# Epoch 7 / 50
# ----------
# Train Loss: 0.2182 Acc: 94.3590 F1: 0.9436 | Val Loss: 0.1074 Acc: 97.5469% F1: 0.9757 | Epoch time: 1m 37s
#
# Epoch 8 / 50
# ----------
# Train Loss: 0.2080 Acc: 94.4391 F1: 0.9444 | Val Loss: 0.1008 Acc: 97.4988% F1: 0.9750 | Epoch time: 1m 36s
#
# Epoch 9 / 50
# ----------
# Train Loss: 0.1943 Acc: 94.6314 F1: 0.9463 | Val Loss: 0.0963 Acc: 97.7874% F1: 0.9778 | Epoch time: 1m 36s
#
# Epoch 10 / 50
# ----------
# Train Loss: 0.1869 Acc: 94.5353 F1: 0.9455 | Val Loss: 0.0864 Acc: 98.0279% F1: 0.9803 | Epoch time: 1m 36s
#
# Epoch 11 / 50
# ----------
# Train Loss: 0.1718 Acc: 95.3846 F1: 0.9538 | Val Loss: 0.0884 Acc: 97.6912% F1: 0.9769 | Epoch time: 1m 36s
#
# Epoch 12 / 50
# ----------
# Train Loss: 0.1682 Acc: 95.2724 F1: 0.9527 | Val Loss: 0.0993 Acc: 97.1140% F1: 0.9714 | Epoch time: 1m 36s
#
# Epoch 13 / 50
# ----------
# Train Loss: 0.1610 Acc: 95.5769 F1: 0.9558 | Val Loss: 0.0802 Acc: 98.1241% F1: 0.9815 | Epoch time: 1m 36s
#
# Epoch 14 / 50
# ----------
# Train Loss: 0.1646 Acc: 95.5128 F1: 0.9551 | Val Loss: 0.0713 Acc: 98.2684% F1: 0.9827 | Epoch time: 1m 38s
#
# Epoch 15 / 50
# ----------
# Train Loss: 0.1457 Acc: 96.1058 F1: 0.9611 | Val Loss: 0.0738 Acc: 98.2203% F1: 0.9821 | Epoch time: 1m 36s
#
# Epoch 16 / 50
# ----------
# Train Loss: 0.1406 Acc: 95.7853 F1: 0.9578 | Val Loss: 0.0773 Acc: 97.5950% F1: 0.9756 | Epoch time: 1m 36s
#
# Epoch 17 / 50
# ----------
# Train Loss: 0.1392 Acc: 95.9936 F1: 0.9599 | Val Loss: 0.0742 Acc: 97.9798% F1: 0.9799 | Epoch time: 1m 37s
#
# Epoch 18 / 50
# ----------
# Train Loss: 0.1342 Acc: 96.4423 F1: 0.9644 | Val Loss: 0.0680 Acc: 98.1241% F1: 0.9813 | Epoch time: 1m 37s
#
# Epoch 19 / 50
# ----------
# Train Loss: 0.1412 Acc: 96.1218 F1: 0.9612 | Val Loss: 0.0739 Acc: 98.1722% F1: 0.9818 | Epoch time: 1m 37s
#
# Epoch 20 / 50
# ----------
# Train Loss: 0.1325 Acc: 96.4744 F1: 0.9648 | Val Loss: 0.0682 Acc: 98.0279% F1: 0.9803 | Epoch time: 1m 37s
#
# Epoch 21 / 50
# ----------
# Train Loss: 0.1298 Acc: 96.3301 F1: 0.9633 | Val Loss: 0.0600 Acc: 98.5570% F1: 0.9856 | Epoch time: 1m 37s
#
# Epoch 22 / 50
# ----------
# Train Loss: 0.1317 Acc: 96.3462 F1: 0.9635 | Val Loss: 0.0666 Acc: 98.2684% F1: 0.9827 | Epoch time: 1m 37s
#
# Epoch 23 / 50
# ----------
# Train Loss: 0.1254 Acc: 96.6667 F1: 0.9667 | Val Loss: 0.0635 Acc: 98.4127% F1: 0.9841 | Epoch time: 1m 37s
#
# Epoch 24 / 50
# ----------
# Train Loss: 0.1197 Acc: 96.4423 F1: 0.9644 | Val Loss: 0.0576 Acc: 98.5570% F1: 0.9856 | Epoch time: 1m 37s
#
# Epoch 25 / 50
# ----------
# Train Loss: 0.1181 Acc: 96.3782 F1: 0.9638 | Val Loss: 0.0618 Acc: 98.5089% F1: 0.9852 | Epoch time: 1m 37s
#
# Epoch 26 / 50
# ----------
# Train Loss: 0.1185 Acc: 96.3622 F1: 0.9637 | Val Loss: 0.0571 Acc: 98.5570% F1: 0.9856 | Epoch time: 1m 36s
#
# Epoch 27 / 50
# ----------
# Train Loss: 0.1300 Acc: 96.5224 F1: 0.9652 | Val Loss: 0.0643 Acc: 98.0760% F1: 0.9809 | Epoch time: 1m 36s
#
# Epoch 28 / 50
# ----------
# Train Loss: 0.1181 Acc: 96.8269 F1: 0.9682 | Val Loss: 0.0578 Acc: 98.3165% F1: 0.9832 | Epoch time: 1m 37s
#
# Epoch 29 / 50
# ----------
# Train Loss: 0.1094 Acc: 97.0032 F1: 0.9701 | Val Loss: 0.0582 Acc: 98.5089% F1: 0.9850 | Epoch time: 1m 37s
#
# Epoch 30 / 50
# ----------
# Train Loss: 0.1121 Acc: 96.7308 F1: 0.9672 | Val Loss: 0.0541 Acc: 98.6532% F1: 0.9865 | Epoch time: 1m 37s
#
# Epoch 31 / 50
# ----------
# Train Loss: 0.1163 Acc: 96.7468 F1: 0.9674 | Val Loss: 0.0550 Acc: 98.4608% F1: 0.9846 | Epoch time: 1m 37s
#
# Epoch 32 / 50
# ----------
# Train Loss: 0.1128 Acc: 96.6827 F1: 0.9668 | Val Loss: 0.0540 Acc: 98.5089% F1: 0.9852 | Epoch time: 1m 37s
#
# Epoch 33 / 50
# ----------
# Train Loss: 0.1147 Acc: 96.6987 F1: 0.9670 | Val Loss: 0.0480 Acc: 98.9899% F1: 0.9899 | Epoch time: 1m 37s
#
# Epoch 34 / 50
# ----------
# Train Loss: 0.1053 Acc: 97.0833 F1: 0.9708 | Val Loss: 0.0557 Acc: 98.3165% F1: 0.9832 | Epoch time: 1m 36s
#
# Epoch 35 / 50
# ----------
# Train Loss: 0.1046 Acc: 97.0192 F1: 0.9702 | Val Loss: 0.0564 Acc: 98.2203% F1: 0.9822 | Epoch time: 1m 37s
#
# Epoch 36 / 50
# ----------
# Train Loss: 0.1342 Acc: 96.3942 F1: 0.9640 | Val Loss: 0.0510 Acc: 98.5570% F1: 0.9856 | Epoch time: 1m 36s
#
# Epoch 37 / 50
# ----------
# Train Loss: 0.1010 Acc: 97.1955 F1: 0.9720 | Val Loss: 0.0559 Acc: 98.4127% F1: 0.9841 | Epoch time: 1m 36s
#
# Epoch 38 / 50
# ----------
# Train Loss: 0.1071 Acc: 96.9712 F1: 0.9697 | Val Loss: 0.0563 Acc: 98.5570% F1: 0.9855 | Epoch time: 1m 37s
#
# Epoch 39 / 50
# ----------
# Train Loss: 0.1059 Acc: 96.9071 F1: 0.9690 | Val Loss: 0.0520 Acc: 98.7494% F1: 0.9875 | Epoch time: 1m 37s
#
# Epoch 40 / 50
# ----------
# Train Loss: 0.1123 Acc: 96.8590 F1: 0.9686 | Val Loss: 0.0540 Acc: 98.6532% F1: 0.9865 | Epoch time: 1m 36s
#
# Epoch 41 / 50
# ----------
# Train Loss: 0.1107 Acc: 96.9231 F1: 0.9693 | Val Loss: 0.0523 Acc: 98.7494% F1: 0.9876 | Epoch time: 1m 36s
#
# Epoch 42 / 50
# ----------
# Train Loss: 0.1041 Acc: 96.9551 F1: 0.9696 | Val Loss: 0.0498 Acc: 98.7975% F1: 0.9880 | Epoch time: 1m 36s
#
# Epoch 43 / 50
# ----------
# Train Loss: 0.0984 Acc: 97.0673 F1: 0.9706 | Val Loss: 0.0497 Acc: 98.7013% F1: 0.9870 | Epoch time: 1m 37s
#
# Epoch 44 / 50
# ----------
# Train Loss: 0.1054 Acc: 96.9712 F1: 0.9697 | Val Loss: 0.0487 Acc: 98.8456% F1: 0.9884 | Epoch time: 1m 37s
#
# Epoch 45 / 50
# ----------
# Train Loss: 0.0936 Acc: 97.3077 F1: 0.9731 | Val Loss: 0.0519 Acc: 98.2203% F1: 0.9822 | Epoch time: 1m 36s
#
# Epoch 46 / 50
# ----------
# Train Loss: 0.0927 Acc: 97.4840 F1: 0.9749 | Val Loss: 0.0562 Acc: 98.3646% F1: 0.9837 | Epoch time: 1m 36s
#
# Epoch 47 / 50
# ----------
# Train Loss: 0.1018 Acc: 97.3558 F1: 0.9735 | Val Loss: 0.0500 Acc: 98.6532% F1: 0.9866 | Epoch time: 1m 36s
#
# Epoch 48 / 50
# ----------
# Train Loss: 0.0808 Acc: 97.7885 F1: 0.9779 | Val Loss: 0.0499 Acc: 98.7975% F1: 0.9880 | Epoch time: 1m 37s
#
# Epoch 49 / 50
# ----------
# Train Loss: 0.0896 Acc: 97.4359 F1: 0.9743 | Val Loss: 0.0476 Acc: 98.7975% F1: 0.9880 | Epoch time: 1m 36s
#
# Epoch 50 / 50
# ----------
# Train Loss: 0.0858 Acc: 97.4519 F1: 0.9745 | Val Loss: 0.0482 Acc: 98.6051% F1: 0.9861 | Epoch time: 1m 36s
#
# Training ConvNeXt no_hidden complete in 80m 21s
# Best val Acc: 98.989899
# Best val F1: 0.989910
# === Model: ConvNeXt | Skenario: with_hidden ===
#
# Epoch 1 / 50
# ----------
# Train Loss: 1.4103 Acc: 63.3333 F1: 0.6341 | Val Loss: 0.3590 Acc: 89.7547% F1: 0.8968 | Epoch time: 1m 36s
#
# Epoch 2 / 50
# ----------
# Train Loss: 0.5678 Acc: 83.3974 F1: 0.8333 | Val Loss: 0.2330 Acc: 93.0255% F1: 0.9299 | Epoch time: 1m 37s
#
# Epoch 3 / 50
# ----------
# Train Loss: 0.4361 Acc: 87.3558 F1: 0.8734 | Val Loss: 0.1605 Acc: 95.2381% F1: 0.9523 | Epoch time: 1m 38s
#
# Epoch 4 / 50
# ----------
# Train Loss: 0.3587 Acc: 88.7981 F1: 0.8878 | Val Loss: 0.1497 Acc: 95.4786% F1: 0.9557 | Epoch time: 1m 36s
#
# Epoch 5 / 50
# ----------
# Train Loss: 0.3380 Acc: 89.5032 F1: 0.8949 | Val Loss: 0.1278 Acc: 95.9596% F1: 0.9605 | Epoch time: 1m 36s
#
# Epoch 6 / 50
# ----------
# Train Loss: 0.2868 Acc: 91.5705 F1: 0.9156 | Val Loss: 0.1094 Acc: 97.0659% F1: 0.9710 | Epoch time: 1m 36s
#
# Epoch 7 / 50
# ----------
# Train Loss: 0.2769 Acc: 91.6026 F1: 0.9160 | Val Loss: 0.0799 Acc: 97.6431% F1: 0.9765 | Epoch time: 1m 36s
#
# Epoch 8 / 50
# ----------
# Train Loss: 0.2700 Acc: 91.6667 F1: 0.9165 | Val Loss: 0.0758 Acc: 97.9798% F1: 0.9796 | Epoch time: 1m 37s
#
# Epoch 9 / 50
# ----------
# Train Loss: 0.2294 Acc: 92.6282 F1: 0.9263 | Val Loss: 0.0771 Acc: 97.6912% F1: 0.9771 | Epoch time: 1m 36s
#
# Epoch 10 / 50
# ----------
# Train Loss: 0.2316 Acc: 92.7083 F1: 0.9271 | Val Loss: 0.0727 Acc: 98.1241% F1: 0.9812 | Epoch time: 1m 36s
#
# Epoch 11 / 50
# ----------
# Train Loss: 0.2642 Acc: 91.8590 F1: 0.9187 | Val Loss: 0.0695 Acc: 98.1722% F1: 0.9815 | Epoch time: 1m 37s
#
# Epoch 12 / 50
# ----------
# Train Loss: 0.2204 Acc: 93.1410 F1: 0.9313 | Val Loss: 0.0740 Acc: 98.0279% F1: 0.9805 | Epoch time: 1m 39s
#
# Epoch 13 / 50
# ----------
# Train Loss: 0.2015 Acc: 94.1346 F1: 0.9414 | Val Loss: 0.0654 Acc: 98.1241% F1: 0.9814 | Epoch time: 1m 36s
#
# Epoch 14 / 50
# ----------
# Train Loss: 0.2320 Acc: 93.3013 F1: 0.9331 | Val Loss: 0.0654 Acc: 98.0279% F1: 0.9803 | Epoch time: 1m 36s
#
# Epoch 15 / 50
# ----------
# Train Loss: 0.2059 Acc: 93.4135 F1: 0.9341 | Val Loss: 0.0628 Acc: 98.5089% F1: 0.9852 | Epoch time: 1m 36s
#
# Epoch 16 / 50
# ----------
# Train Loss: 0.1785 Acc: 94.5513 F1: 0.9455 | Val Loss: 0.0654 Acc: 98.4127% F1: 0.9842 | Epoch time: 1m 37s
#
# Epoch 17 / 50
# ----------
# Train Loss: 0.2047 Acc: 93.8141 F1: 0.9381 | Val Loss: 0.0551 Acc: 98.6051% F1: 0.9861 | Epoch time: 1m 36s
#
# Epoch 18 / 50
# ----------
# Train Loss: 0.1965 Acc: 94.1506 F1: 0.9416 | Val Loss: 0.0548 Acc: 98.4127% F1: 0.9843 | Epoch time: 1m 36s
#
# Epoch 19 / 50
# ----------
# Train Loss: 0.1845 Acc: 94.3429 F1: 0.9435 | Val Loss: 0.0587 Acc: 98.5089% F1: 0.9851 | Epoch time: 1m 36s
#
# Epoch 20 / 50
# ----------
# Train Loss: 0.1860 Acc: 94.2628 F1: 0.9426 | Val Loss: 0.0527 Acc: 98.5089% F1: 0.9851 | Epoch time: 1m 36s
#
# Epoch 21 / 50
# ----------
# Train Loss: 0.1868 Acc: 94.3910 F1: 0.9439 | Val Loss: 0.0440 Acc: 98.8937% F1: 0.9890 | Epoch time: 1m 37s
#
# Epoch 22 / 50
# ----------
# Train Loss: 0.1918 Acc: 94.4231 F1: 0.9441 | Val Loss: 0.0451 Acc: 98.7494% F1: 0.9876 | Epoch time: 1m 36s
#
# Epoch 23 / 50
# ----------
# Train Loss: 0.1659 Acc: 94.7756 F1: 0.9478 | Val Loss: 0.0534 Acc: 98.6051% F1: 0.9861 | Epoch time: 1m 36s
#
# Epoch 24 / 50
# ----------
# Train Loss: 0.1741 Acc: 94.8237 F1: 0.9482 | Val Loss: 0.0816 Acc: 97.6431% F1: 0.9767 | Epoch time: 1m 36s
#
# Epoch 25 / 50
# ----------
# Train Loss: 0.1944 Acc: 94.5513 F1: 0.9455 | Val Loss: 0.0579 Acc: 98.3165% F1: 0.9832 | Epoch time: 1m 37s
#
# Epoch 26 / 50
# ----------
# Train Loss: 0.1672 Acc: 95.2244 F1: 0.9523 | Val Loss: 0.0560 Acc: 98.4608% F1: 0.9847 | Epoch time: 1m 37s
#
# Epoch 27 / 50
# ----------
# Train Loss: 0.1764 Acc: 95.1603 F1: 0.9516 | Val Loss: 0.0526 Acc: 98.6051% F1: 0.9861 | Epoch time: 1m 36s
#
# Epoch 28 / 50
# ----------
# Train Loss: 0.1650 Acc: 95.1763 F1: 0.9517 | Val Loss: 0.0560 Acc: 98.4127% F1: 0.9842 | Epoch time: 1m 36s
#
# Epoch 29 / 50
# ----------
# Train Loss: 0.1650 Acc: 95.1442 F1: 0.9514 | Val Loss: 0.0526 Acc: 98.5570% F1: 0.9856 | Epoch time: 1m 37s
#
# Epoch 30 / 50
# ----------
# Train Loss: 0.1762 Acc: 94.9359 F1: 0.9493 | Val Loss: 0.0555 Acc: 98.4608% F1: 0.9847 | Epoch time: 1m 37s
#
# Epoch 31 / 50
# ----------
# Train Loss: 0.1876 Acc: 94.7276 F1: 0.9473 | Val Loss: 0.0498 Acc: 98.6532% F1: 0.9866 | Epoch time: 1m 38s
#
# Epoch 32 / 50
# ----------
# Train Loss: 0.1763 Acc: 94.6314 F1: 0.9464 | Val Loss: 0.0574 Acc: 98.7494% F1: 0.9875 | Epoch time: 1m 37s
#
# Epoch 33 / 50
# ----------
# Train Loss: 0.1789 Acc: 94.8077 F1: 0.9481 | Val Loss: 0.0605 Acc: 98.6532% F1: 0.9865 | Epoch time: 1m 37s
#
# Epoch 34 / 50
# ----------
# Train Loss: 0.1787 Acc: 94.7756 F1: 0.9477 | Val Loss: 0.0571 Acc: 98.4127% F1: 0.9843 | Epoch time: 1m 37s
#
# Epoch 35 / 50
# ----------
# Train Loss: 0.1624 Acc: 95.0801 F1: 0.9508 | Val Loss: 0.0571 Acc: 98.7013% F1: 0.9870 | Epoch time: 1m 37s
#
# Epoch 36 / 50
# ----------
# Train Loss: 0.1458 Acc: 95.6410 F1: 0.9564 | Val Loss: 0.0674 Acc: 98.2684% F1: 0.9828 | Epoch time: 1m 36s
#
# Epoch 37 / 50
# ----------
# Train Loss: 0.1654 Acc: 95.0641 F1: 0.9506 | Val Loss: 0.0580 Acc: 98.6532% F1: 0.9865 | Epoch time: 1m 37s
#
# Epoch 38 / 50
# ----------
# Train Loss: 0.1645 Acc: 95.2564 F1: 0.9526 | Val Loss: 0.0461 Acc: 98.9418% F1: 0.9894 | Epoch time: 1m 37s
#
# Epoch 39 / 50
# ----------
# Train Loss: 0.1734 Acc: 94.6154 F1: 0.9462 | Val Loss: 0.0498 Acc: 98.9418% F1: 0.9894 | Epoch time: 1m 38s
#
# Epoch 40 / 50
# ----------
# Train Loss: 0.1595 Acc: 94.9199 F1: 0.9493 | Val Loss: 0.0501 Acc: 98.8456% F1: 0.9884 | Epoch time: 1m 37s
#
# Epoch 41 / 50
# ----------
# Train Loss: 0.1500 Acc: 95.2885 F1: 0.9529 | Val Loss: 0.0524 Acc: 98.7494% F1: 0.9875 | Epoch time: 1m 37s
#
# Epoch 42 / 50
# ----------
# Train Loss: 0.1568 Acc: 95.2244 F1: 0.9522 | Val Loss: 0.0486 Acc: 98.8456% F1: 0.9884 | Epoch time: 1m 37s
#
# Epoch 43 / 50
# ----------
# Train Loss: 0.1490 Acc: 95.6250 F1: 0.9563 | Val Loss: 0.0511 Acc: 98.7013% F1: 0.9871 | Epoch time: 1m 37s
#
# Epoch 44 / 50
# ----------
# Train Loss: 0.1627 Acc: 95.3205 F1: 0.9532 | Val Loss: 0.0493 Acc: 98.9899% F1: 0.9899 | Epoch time: 1m 37s
#
# Epoch 45 / 50
# ----------
# Train Loss: 0.1635 Acc: 95.7692 F1: 0.9577 | Val Loss: 0.0633 Acc: 98.6532% F1: 0.9866 | Epoch time: 1m 37s
#
# Epoch 46 / 50
# ----------
# Train Loss: 0.1586 Acc: 95.5609 F1: 0.9556 | Val Loss: 0.0484 Acc: 98.9899% F1: 0.9899 | Epoch time: 1m 37s
#
# Epoch 47 / 50
# ----------
# Train Loss: 0.1516 Acc: 95.4968 F1: 0.9550 | Val Loss: 0.0500 Acc: 98.7975% F1: 0.9880 | Epoch time: 1m 37s
#
# Epoch 48 / 50
# ----------
# Train Loss: 0.1599 Acc: 95.7372 F1: 0.9574 | Val Loss: 0.0423 Acc: 99.1342% F1: 0.9913 | Epoch time: 1m 37s
#
# Epoch 49 / 50
# ----------
# Train Loss: 0.1577 Acc: 95.3846 F1: 0.9539 | Val Loss: 0.0493 Acc: 98.9418% F1: 0.9895 | Epoch time: 1m 37s
#
# Epoch 50 / 50
# ----------
# Train Loss: 0.1569 Acc: 95.4808 F1: 0.9548 | Val Loss: 0.0478 Acc: 98.8456% F1: 0.9885 | Epoch time: 1m 37s
#
# Training ConvNeXt with_hidden complete in 80m 32s
# Best val Acc: 99.134199
# Best val F1: 0.991321

# %%
# Simpan hasil train & val
results_training_df = pd.DataFrame(results_training)
results_training_df.to_csv('C:/Users/ASUS/Coding/Jupiter/PRTA/train&val_results.csv', index=False)
print(results_training_df)
# Out:
#     model_name     scenario   train_time  \
# 0     ResNet50    no_hidden  3830.505871
# 1     ResNet50  with_hidden  3831.400132
# 2  DenseNet121    no_hidden  3942.061292
# 3  DenseNet121  with_hidden  3948.527492
# 4  MobileNetV3    no_hidden  2392.503314
# 5  MobileNetV3  with_hidden  2394.966484
# 6     ConvNeXt    no_hidden  4820.545798
# 7     ConvNeXt  with_hidden  4832.236090
#
#                                              history
# 0  {'train_loss': [2.0074339059682993, 0.92671043...
# 1  {'train_loss': [2.92226304152073, 1.7252112645...
# 2  {'train_loss': [2.4313161752162835, 1.14239678...
# 3  {'train_loss': [2.6665831247965497, 1.39443641...
# 4  {'train_loss': [1.313806320917912, 0.649918871...
# 5  {'train_loss': [1.5556550949047774, 0.78574234...
# 6  {'train_loss': [1.4494801678718665, 0.54781465...
# 7  {'train_loss': [1.410251897573471, 0.567810468...

# %%
# Multi-Line Chart | Acc & F1 | Val
def plot_metric_comparison(results_training_df, metric='acc'):
    plt.figure(figsize=(12, 9))
    palette = {
        'ResNet50': 'blue',
        'DenseNet121': 'green',
        'MobileNetV3': 'red',
        'ConvNeXt': 'purple'
    }

    styles = {
        'no_hidden': 'dashed',
        'with_hidden': 'solid'
    }

    legend_items = []

    for model in results_training_df['model_name'].unique():
        for scenario in ['no_hidden', 'with_hidden']:
            subset = results_training_df[
                (results_training_df['model_name'] == model) & (results_training_df['scenario'] == scenario)
            ]
            if not subset.empty:
                history = subset.iloc[0]['history']
                val_metric = history[f'val_{metric}']
                best_epoch = max(range(len(val_metric)), key=lambda i: val_metric[i])
                best_value = val_metric[best_epoch]

                label = f"{model} ({scenario.replace('_', ' ')}) - max {best_value:.3f} @ {best_epoch+1}"
                legend_items.append(label)

                plt.plot(
                    val_metric, 
                    linestyle=styles[scenario],
                    color=palette[model],
                    linewidth=2,
                    alpha=0.8,
                    label=label
                )

                # Mark the best point
                plt.scatter(
                    best_epoch, best_value,
                    color=palette[model],
                    edgecolor='black',
                    zorder=5
                )

                # Add value text
                plt.text(
                    best_epoch, best_value - 0.02,
                    f"{best_value:.3f}",
                    ha='center',
                    va='top',
                    fontsize=8,
                    color='black'
                )

    plt.title(f'Perbandingan Validasi {metric.upper()} Antar Model', weight='bold')
    plt.xlabel('Epoch')
    plt.ylabel(f'Validasi {metric.upper()}')
    if max(val_metric) > 1.0:
        plt.ylim(60, 100)
    else :
        plt.ylim(0.6, 1)
    plt.grid(True, alpha=0.3)
    plt.legend(title="Model & Skenario", loc='lower right', frameon=True)
    plt.tight_layout()
    plt.savefig(f'C:/Users/ASUS/Coding/Jupiter/PRTA/val_{metric}_comparison.png', bbox_inches='tight')
    plt.show()

# Plot untuk akurasi
plot_metric_comparison(results_training_df, metric='acc')

# Plot untuk F1-score
plot_metric_comparison(results_training_df, metric='f1')
